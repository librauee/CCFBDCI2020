# %%
import math
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.decomposition import LatentDirichletAllocation, NMF, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import f1_score, fbeta_score, precision_score, recall_score, roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from tqdm import tqdm
import warnings
from datetime import datetime

warnings.filterwarnings('ignore')

# load data
annual_report_info = pd.read_csv('./train/annual_report_info.csv')
base_info = pd.read_csv('./train/base_info.csv')
change_info = pd.read_csv('./train/change_info.csv')
entprise_info = pd.read_csv('./train/entprise_info.csv')
news_info = pd.read_csv('./train/news_info.csv')
other_info = pd.read_csv('./train/other_info.csv')
tax_info = pd.read_csv('./train/tax_info.csv')
entprise_evaluate = pd.read_csv('./entprise_evaluate.csv')


data = pd.concat([entprise_info, entprise_evaluate.rename(columns={'score': 'label'})], ignore_index=True)

# %%
# extract features

def kfold_mean(df_train, df_test, target, target_mean_list):
    folds = StratifiedKFold(n_splits=5)

    mean_of_target = df_train[target].mean()

    for fold_, (trn_idx, val_idx) in tqdm(
            enumerate(folds.split(df_train, y=df_train['label']))):
        tr_x = df_train.iloc[trn_idx, :]
        vl_x = df_train.iloc[val_idx, :]

        for col in target_mean_list:
            df_train.loc[vl_x.index, f'{col}_target_enc'] = vl_x[col].map(
                tr_x.groupby(col)[target].mean())

    for col in target_mean_list:
        df_train[f'{col}_target_enc'].fillna(mean_of_target, inplace=True)

        df_test[f'{col}_target_enc'] = df_test[col].map(
            df_train.groupby(col)[f'{col}_target_enc'].mean())

        df_test[f'{col}_target_enc'].fillna(mean_of_target, inplace=True)
    return pd.concat([df_train, df_test], ignore_index=True)

# %%
def extract_base_info_info(data):
    data['district_FLAG1'] = (data['orgid'].fillna('').apply(lambda x: str(x)[:6]) ==
                              data['oplocdistrict'].fillna('').apply(lambda x: str(x)[:6])).astype(int)
    data['district_FLAG2'] = (data['orgid'].fillna('').apply(lambda x: str(x)[:6]) ==
                              data['jobid'].fillna('').apply(lambda x: str(x)[:6])).astype(int)
    data['district_FLAG3'] = (data['oplocdistrict'].fillna('').apply(lambda x: str(x)[:6]) ==
                              data['jobid'].fillna('').apply(lambda x: str(x)[:6])).astype(int)

    data['person_SUM'] = data[['empnum', 'parnum', 'exenum']].sum(1)
    data['person_NULL_SUM'] = data[['empnum', 'parnum', 'exenum']].isnull().astype(int).sum(1)

    data['empnum'] = data['empnum'].fillna(-1)
    data['compform'] = data['compform'].fillna(-1)
    data['parnum'] = data['parnum'].fillna(-1)
    data['exenum'] = data['exenum'].fillna(-1)
    data['opform'] = data['opform'].fillna('-1')
    data['venind'] = data['venind'].fillna(-1)
    data['reccap'] = data['reccap'].fillna(-1)
    data['regcap'] = data['regcap'].fillna(-1)
    data['venind_isna'] = (data['venind'] < 0).astype(np.int8)
    data['reccap_isna'] = (data['reccap'] < 0).astype(np.int8)
    data['regcap_isna'] = (data['regcap'] < 0).astype(np.int8)
    data['enttypeitem'] = data['enttypeitem'].fillna(-1)
    data['enttypeminu'] = data['enttypeminu'].fillna(-1)

    # 未缺失数目
    data['not_na_count'] = 0
    for i in range(len(data)):
        if not math.isnan(data['congro'][i]):
            data['not_na_count'][i] += 1
        if not math.isnan(data['protype'][i]):
            data['not_na_count'][i] += 1
        if not math.isnan(data['forreccap'][i]):
            data['not_na_count'][i] += 1
        if not math.isnan(data['forregcap'][i]):
            data['not_na_count'][i] += 1

    drop = ['ptbusscope', 'midpreindcode',
            'protype', 'forreccap',
            'forregcap', 'congro']
    for f in drop:
        del data[f]

    data['opto'] = data['opto'].fillna('3099-12-31')
    data['opto_isna'] = (data['opto'].apply(lambda x: int(x.split('-')[0]) == 3099)).astype(np.int8)
    data['year_to'] = data['opto'].apply(lambda x: int(x.split('-')[0]))
    data['year_from'] = data['opfrom'].apply(lambda x: int(x.split('-')[0]))
    data['year_range'] = data['year_to'] - data['year_from']
    del data['opfrom']
    del data['opto']
    data['cap_diff'] = data['reccap'] - data['regcap']

    data['dom_len'] = data['dom'].apply(lambda x: len(x) / 16)
    data['oploc_len'] = data['oploc'].apply(lambda x: len(x) / 16)
    data['oploc'] = data['oploc'].apply(lambda x: x[:16])
    data['len_diff'] = data.apply(lambda x: x['oploc_len'] - x['dom_len'], axis=1)
    data['opscope_legal'] = data['opscope'].apply(lambda x: 1 if '依法须经批准的项目' in x else 0)
    del data['dom'], data['opscope']

    lb = LabelEncoder()
    data['industryphy'] = lb.fit_transform(data['industryphy'])
    data['opform'] = lb.fit_transform(data['opform'])
    data['oploc'] = lb.fit_transform(data['oploc'])
    data['industryco'] = lb.fit_transform(data['industryco'])

    # count encode
    for col in ['oplocdistrict', 'industryphy', 'enttype', 'state', 'orgid',
                'adbusign', 'townsign', 'oploc', 'regtype', 'enttypegb',
                'enttypeitem', 'enttypeminu', 'jobid', 'industryco']:
        data[col + '_COUNT'] = data[col].map(data[col].value_counts())
        col_idx = data[col].value_counts()
        for idx in col_idx[col_idx < 10].index:
            data[col] = data[col].replace(idx, -1)

    data = kfold_mean(data[~data['label'].isna()], data[data['label'].isna()], 'label',
                      ['oplocdistrict', 'industryphy', 'enttype', 'state', 'orgid',
                       'adbusign', 'townsign', 'oploc', 'regtype', 'enttypegb',
                       'enttypeitem', 'enttypeminu', 'jobid', 'industryco'])

    return data

# %%
def extract_annual_report_info(annual_report_):
    annual_report = annual_report_.copy().sort_values(by=['id', 'ANCHEYEAR'])
    result = annual_report.groupby('id').agg(
        {
            'ANCHEYEAR': ['nunique', lambda x: x.diff().max(), lambda x: x.diff().mean()],
            'EMPNUM': ['mean', 'std', lambda x: x.diff().mean(), lambda x: x.diff().std()],
            'COLGRANUM': ['mean', 'std'],
            'RETSOLNUM': ['mean', 'std'],
            'DISPERNUM': ['mean', 'std'],
            'UNENUM': ['mean', 'std'],
            'COLEMPLNUM': ['mean', 'std'],
            'RETEMPLNUM': ['mean', 'std'],
            'DISEMPLNUM': ['mean', 'std'],
            'UNEEMPLNUM': ['mean', 'std']
        }
    ).reset_index()
    result.columns = ['id',
                      'year_nunique',
                      'year_diff_max',
                      'year_diff_mean',
                      'EMPNUM_mean',
                      'EMPNUM_std',
                      'EMPNUM_diff_mean',
                      'EMPNUM_diff_std',
                      'COLGRANUM_mean',
                      'COLGRANUM_std',
                      'RETSOLNUM_mean',
                      'RETSOLNUM_std',
                      'DISPERNUM_mean',
                      'DISPERNUM_std',
                      'UNENUM_mean',
                      'UNENUM_std',
                      'COLEMPLNUM_mean',
                      'COLEMPLNUM_std',
                      'RETEMPLNUM_mean',
                      'RETEMPLNUM_std',
                      'DISEMPLNUM_mean',
                      'DISEMPLNUM_std',
                      'UNEEMPLNUM_mean',
                      'UNEEMPLNUM_std']

    for f in ['STATE', 'BUSSTNAME', 'PUBSTATE', 'EMPNUMSIGN', 'WEBSITSIGN', 'FORINVESTSIGN', 'STOCKTRANSIGN']:
        result[[f'{f}_count_vec_{i}' for i in range(annual_report[f].nunique(dropna=False))]] = pd.DataFrame(
            CountVectorizer(vocabulary=annual_report[f].unique().astype(str)).fit_transform(
                annual_report.groupby('id')[f].apply(lambda x: ' '.join(list(x.astype(str))))).toarray(),
            index=result.index)
    return result

# %%
def extract_change_info(change):
    result = change.groupby('id').agg(
        {
            'bgxmdm': ['nunique', lambda x: x.nunique() / len(x)],
            'bgq': ['nunique', lambda x: x.nunique() / len(x)],
            'bgh': ['nunique', lambda x: x.nunique() / len(x)]
        }
    ).reset_index()
    result.columns = ['id', 'bgxmdm_nunique', 'bgxmdm_nunique_rto', 'bgq_nunique', 'bgq_nunique_rto', 'bgh_nunique',
                      'bgh_nunique_rto']
    return result


def extract_other_info(others):
    others['other_SUM'] = others[['legal_judgment_num', 'brand_num', 'patent_num']].sum(1)
    others['other_NULL_SUM'] = others[['legal_judgment_num', 'brand_num', 'patent_num']].isnull().astype(
        int).sum(1)
    result = others.groupby('id').agg(
        {
            'other_SUM': ['mean'],
            'other_NULL_SUM': ['mean']
        }
    ).reset_index()
    result.columns = ['id',
                      'other_SUM',
                      'other_NULL_SUM']
    return result

# %%
def extract_news_info(news):
    news_info['public_date'] = news_info['public_date'].apply(lambda x: x if '-' in str(x) else np.nan)
    news_info['public_date'] = pd.to_datetime(news_info['public_date'])
    news_info['public_date'] = (datetime.now() - news_info['public_date']).dt.days

    result = news.groupby('id').agg({'public_date': ['count']}).reset_index()
    result.columns = ['id', 'public_date_COUNT']
    for f in ['positive_negtive']:
        result[[f'{f}_count_vec_{i}' for i in range(news[f].nunique(dropna=False))]] = pd.DataFrame(
            CountVectorizer(vocabulary=news[f].unique().astype(str)).fit_transform(
                news.groupby('id')[f].apply(lambda x: ' '.join(list(x.astype(str))))).toarray(),
            index=result.index)
    return result

# %%
def extract_tax_info(tax):
    tax['income'] = tax['TAX_AMOUNT'] / tax['TAX_RATE']
    result = tax.groupby('id').agg(
        {
            'TAX_CATEGORIES': ['count'],
            'TAX_ITEMS': ['count'],
            'TAXATION_BASIS': ['mean', 'std', 'count'],
            'TAX_RATE': ['mean', 'std'],
            'TAX_AMOUNT': ['mean', 'std', 'max', 'min'],
        }
    ).reset_index()
    result.columns = ['id',
                      'TAX_CATEGORIES_count',
                      'TAX_ITEMS_count',
                      'TAXATION_BASIS_mean',
                      'TAXATION_BASIS_std',
                      'TAXATION_BASIS_count',
                      'TAX_RATE_mean',
                      'TAX_RATE_std',
                      'TAX_AMOUNT_mean',
                      'TAX_AMOUNT_std',
                      'TAX_AMOUNT_max',
                      'TAX_AMOUNT_min',
                      ]

    for f in ['TAX_CATEGORIES']:
        result[[f'{f}_count_vec_{i}' for i in range(tax[f].nunique(dropna=False))]] = pd.DataFrame(
            CountVectorizer(vocabulary=tax[f].unique().astype(str)).fit_transform(
                tax.groupby('id')[f].apply(lambda x: ' '.join(list(x.astype(str))))).toarray(),
            index=result.index)

    # tax_items_tfidf
    tax_items_tfidf = TfidfVectorizer(vocabulary=tax['TAX_ITEMS'].unique().astype(str), min_df=20).fit_transform(
        tax.groupby('id').apply(lambda x: ' '.join(list(x))).tolist())

    lda = LatentDirichletAllocation(n_jobs=-1, n_components=8)
    result[[
        f'lda_tax_items{i + 1}' for i in range(lda.n_components)
    ]] = pd.DataFrame(lda.fit_transform(
        tax_items_tfidf),
        index=result.index)

    nmf = NMF(n_components=8)
    result[[
        f'nmf_tax_items{i + 1}' for i in range(nmf.n_components)
    ]] = pd.DataFrame(nmf.fit_transform(
        tax_items_tfidf),
        index=result.index)

    svd = TruncatedSVD(n_components=8)
    result[[
        f'svd_tax_items{i + 1}' for i in range(svd.n_components)
    ]] = pd.DataFrame(svd.fit_transform(
        tax_items_tfidf),
        index=result.index)

    return result

# %%
data = pd.merge(left=data, right=base_info, how='left', on='id')
data = extract_base_info_info(data)
data = data.merge(pd.read_csv('tfidf_decomposition.csv'), how='left', on='id')


def combine_info(data, info_data, extract_func):
    info = extract_func(info_data)
    data = data.merge(info, on='id', how='left')
    return data


for info_data, extract_func in tqdm([
    (annual_report_info, extract_annual_report_info),
    (change_info, extract_change_info),
    (tax_info, extract_tax_info),
    # (other_info, extract_other_info),
    (news_info, extract_news_info),
], desc='extract features'):
    data = combine_info(data, info_data, extract_func)


def filter_col_by_nan(df, ratio=0.05):
    cols = []
    for col in df.columns:
        if df[col].isna().mean() >= (1 - ratio):
            cols.append(col)
    return cols
# Out:
# 5it [00:00, 43.85it/s]
# extract features: 100%|██████████| 4/4 [00:14<00:00,  3.67s/it]

# %%
drop_columns = ['id', 'label']
cat_features = ['oplocdistrict', 'industryphy', 'enttype', 'state',
                'opto_isna', 'industryco', 'oploc', 'orgid', 'adbusign',
                'townsign', 'regtype', 'enttypegb', 'compform', 'jobid',
                'venind', 'enttypeitem', 'enttypeminu', 'opform',
                'opscope_legal', 'regcap_isna', 'reccap_isna', 'venind_isna']
data[cat_features] = data[cat_features].astype('category')
num_features = [f for f in data.columns if f not in drop_columns + cat_features]
data = data.drop(filter_col_by_nan(data[num_features], 0.01), axis=1)
data[num_features] = data[num_features].fillna(-1)
features = num_features
train, X_submit = data[~data['label'].isna()], data[data['label'].isna()]

train['sample_weight'] = 1


# train & predict
def my_metric(y_true, y_pred, sample_weight=None):
    f1 = f1_score(y_true, np.where(y_pred >= 0.5, 1, 0), sample_weight=sample_weight)
    p = precision_score(y_true, np.where(y_pred >= 0.5, 1, 0), sample_weight=sample_weight)
    r = recall_score(y_true, np.where(y_pred >= 0.5, 1, 0), sample_weight=sample_weight)
    return 0.5 * p + 0.3 * r + 0.2 * f1

# %%
def kfold_xgb(train, X_submit, target, param, seed=2023):
    kfout = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    kfin = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    y_pred = target - target
    y_submit = 0

    for fold, (train_index, test_index) in tqdm(enumerate(kfout.split(train, target))):
        X, X_test = train.iloc[train_index], train.iloc[test_index]
        y, y_test = target.iloc[train_index], target.iloc[test_index]
        y_test_hat = 0
        for train_index, val_index in kfin.split(X, y):
            X_train, X_val = X.iloc[train_index], X.iloc[val_index]
            y_train, y_val = y.iloc[train_index], y.iloc[val_index]

            model = xgb.XGBClassifier(n_estimators=2023,
                                      random_state=seed,
                                      n_jobs=-1,
                                      tree_method='hist',
                                      **param
                                      )
            model.fit(X_train[features], y_train, sample_weight=X_train['sample_weight'],
                      eval_set=[(X_train[features], y_train), (X_val[features], y_val)],
                      eval_metric=['auc'], sample_weight_eval_set=[X_train['sample_weight'], X_val['sample_weight']],
                      early_stopping_rounds=25, verbose=2)
            y_test_hat += model.predict_proba(X_test[features])[:, 1] / kfin.n_splits
            y_submit += model.predict_proba(X_submit[features])[:, 1] / (kfin.n_splits * kfout.n_splits)

        fold_f1 = my_metric(y_test, np.where(y_test_hat >= 0.5, 1, 0), sample_weight=X_test['sample_weight'])
        print(f'{fold + 1}fold f1: {fold_f1}')
        y_pred.loc[y_test.index] = y_test_hat

    f1 = my_metric(target, np.where(y_pred >= 0.5, 1, 0), sample_weight=train['sample_weight'])
    auc = roc_auc_score(target, y_pred, sample_weight=train['sample_weight'])
    print(f'all f1: {f1}, auc: {auc}')
    return y_pred, y_submit

# %%
y_pred_all_para = []
y_submit_all_para = []
params = [
    {'max_depth': 12,
     'learning_rate': np.random.uniform(0.004, 0.009),
     'colsample_bytree': np.random.uniform(0.7, 0.85),
     'min_child_weight': 0,
     'reg_alpha': np.random.uniform(0.66, 0.88),
     'reg_lambda': np.random.uniform(1.2, 1.5),
     'subsample': 0.992},
    {'max_depth': 18,
     'learning_rate': np.random.uniform(0.025, 0.065),
     'colsample_bytree': np.random.uniform(0.85, 1),
     'min_child_weight': 0,
     'reg_alpha': np.random.uniform(0.15, 0.55),
     'reg_lambda': np.random.uniform(0.6, 0.9),
     'subsample': 0.996}
]
for i, param in tqdm(enumerate(params)):
    y_pred = 0
    y_submit = 0

    y_pred_seed, y_submit_seed = kfold_xgb(train, X_submit, train['label'], param)
    y_pred += y_pred_seed
    y_submit += y_submit_seed

    f1 = my_metric(train['label'], np.where(y_pred >= 0.5, 1, 0), sample_weight=train['sample_weight'])
    auc = roc_auc_score(train['label'], y_pred, sample_weight=train['sample_weight'])
    print(f'round {i + 1},  all seed f1: {f1}, all seed auc: {auc}')

    y_pred_all_para.append(y_pred)
    y_submit_all_para.append(y_submit)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# [0]	validation_0-auc:0.98678	validation_1-auc:0.99214
# [2]	validation_0-auc:0.99669	validation_1-auc:0.99277
# [4]	validation_0-auc:0.99682	validation_1-auc:0.99333
# [6]	validation_0-auc:0.99683	validation_1-auc:0.99333
# [8]	validation_0-auc:0.99686	validation_1-auc:0.99344
# [10]	validation_0-auc:0.99684	validation_1-auc:0.99349
# [12]	validation_0-auc:0.99681	validation_1-auc:0.99359
# [14]	validation_0-auc:0.99685	validation_1-auc:0.99351
# [16]	validation_0-auc:0.99683	validation_1-auc:0.99357
# [18]	validation_0-auc:0.99694	validation_1-auc:0.99363
# [20]	validation_0-auc:0.99693	validation_1-auc:0.99367
# [22]	validation_0-auc:0.99692	validation_1-auc:0.99379
# [24]	validation_0-auc:0.99693	validation_1-auc:0.99387
# [26]	validation_0-auc:0.99694	validation_1-auc:0.99387
# [28]	validation_0-auc:0.99694	validation_1-auc:0.99383
# [30]	validation_0-auc:0.99703	validation_1-auc:0.99400
# [32]	validation_0-auc:0.99702	validation_1-auc:0.99391
# [34]	validation_0-auc:0.99720	validation_1-auc:0.99390
# [36]	validation_0-auc:0.99727	validation_1-auc:0.99379
# [38]	validation_0-auc:0.99728	validation_1-auc:0.99379
# [40]	validation_0-auc:0.99732	validation_1-auc:0.99382
# [42]	validation_0-auc:0.99735	validation_1-auc:0.99388
# [44]	validation_0-auc:0.99736	validation_1-auc:0.99391
# [46]	validation_0-auc:0.99738	validation_1-auc:0.99391
# [48]	validation_0-auc:0.99740	validation_1-auc:0.99401
# [50]	validation_0-auc:0.99740	validation_1-auc:0.99398
# [52]	validation_0-auc:0.99744	validation_1-auc:0.99399
# [54]	validation_0-auc:0.99746	validation_1-auc:0.99402
# [56]	validation_0-auc:0.99746	validation_1-auc:0.99404
# [58]	validation_0-auc:0.99751	validation_1-auc:0.99409
# [60]	validation_0-auc:0.99758	validation_1-auc:0.99412
# [62]	validation_0-auc:0.99761	validation_1-auc:0.99414
# [64]	validation_0-auc:0.99769	validation_1-auc:0.99429
# [66]	validation_0-auc:0.99773	validation_1-auc:0.99430
# [68]	validation_0-auc:0.99773	validation_1-auc:0.99431
# [70]	validation_0-auc:0.99777	validation_1-auc:0.99427
# [72]	validation_0-auc:0.99780	validation_1-auc:0.99427
# [74]	validation_0-auc:0.99782	validation_1-auc:0.99436
# [76]	validation_0-auc:0.99785	validation_1-auc:0.99434
# [78]	validation_0-auc:0.99785	validation_1-auc:0.99432
# [80]	validation_0-auc:0.99787	validation_1-auc:0.99431
# [82]	validation_0-auc:0.99791	validation_1-auc:0.99427
# [84]	validation_0-auc:0.99792	validation_1-auc:0.99426
# [86]	validation_0-auc:0.99799	validation_1-auc:0.99430
# [88]	validation_0-auc:0.99798	validation_1-auc:0.99431
# [90]	validation_0-auc:0.99800	validation_1-auc:0.99433
# [92]	validation_0-auc:0.99807	validation_1-auc:0.99439
# [94]	validation_0-auc:0.99812	validation_1-auc:0.99442
# [96]	validation_0-auc:0.99815	validation_1-auc:0.99445
# [98]	validation_0-auc:0.99819	validation_1-auc:0.99444
# [100]	validation_0-auc:0.99821	validation_1-auc:0.99448
# [102]	validation_0-auc:0.99822	validation_1-auc:0.99444
# [104]	validation_0-auc:0.99825	validation_1-auc:0.99446
# [106]	validation_0-auc:0.99828	validation_1-auc:0.99450
# [108]	validation_0-auc:0.99831	validation_1-auc:0.99454
# [110]	validation_0-auc:0.99832	validation_1-auc:0.99457
# [112]	validation_0-auc:0.99833	validation_1-auc:0.99458
# [114]	validation_0-auc:0.99835	validation_1-auc:0.99463
# [116]	validation_0-auc:0.99837	validation_1-auc:0.99462
# [118]	validation_0-auc:0.99839	validation_1-auc:0.99469
# [120]	validation_0-auc:0.99842	validation_1-auc:0.99469
# [122]	validation_0-auc:0.99843	validation_1-auc:0.99475
# [124]	validation_0-auc:0.99845	validation_1-auc:0.99472
# [126]	validation_0-auc:0.99847	validation_1-auc:0.99478
# [128]	validation_0-auc:0.99848	validation_1-auc:0.99477
# [130]	validation_0-auc:0.99849	validation_1-auc:0.99480
# [132]	validation_0-auc:0.99850	validation_1-auc:0.99483
# [134]	validation_0-auc:0.99851	validation_1-auc:0.99483
# [136]	validation_0-auc:0.99852	validation_1-auc:0.99483
# [138]	validation_0-auc:0.99854	validation_1-auc:0.99485
# [140]	validation_0-auc:0.99855	validation_1-auc:0.99487
# [142]	validation_0-auc:0.99857	validation_1-auc:0.99491
# [144]	validation_0-auc:0.99858	validation_1-auc:0.99495
# [146]	validation_0-auc:0.99859	validation_1-auc:0.99496
# [148]	validation_0-auc:0.99860	validation_1-auc:0.99496
# [150]	validation_0-auc:0.99861	validation_1-auc:0.99498
# [152]	validation_0-auc:0.99861	validation_1-auc:0.99498
# [154]	validation_0-auc:0.99864	validation_1-auc:0.99499
# [156]	validation_0-auc:0.99865	validation_1-auc:0.99503
# [158]	validation_0-auc:0.99866	validation_1-auc:0.99502
# [160]	validation_0-auc:0.99867	validation_1-auc:0.99505
# [162]	validation_0-auc:0.99868	validation_1-auc:0.99506
# [164]	validation_0-auc:0.99870	validation_1-auc:0.99508
# [166]	validation_0-auc:0.99871	validation_1-auc:0.99507
# [168]	validation_0-auc:0.99872	validation_1-auc:0.99506
# [170]	validation_0-auc:0.99874	validation_1-auc:0.99506
# [172]	validation_0-auc:0.99876	validation_1-auc:0.99509
# [174]	validation_0-auc:0.99877	validation_1-auc:0.99510
# [176]	validation_0-auc:0.99879	validation_1-auc:0.99510
# [178]	validation_0-auc:0.99880	validation_1-auc:0.99509
# [180]	validation_0-auc:0.99881	validation_1-auc:0.99508
# [182]	validation_0-auc:0.99881	validation_1-auc:0.99510
# [184]	validation_0-auc:0.99882	validation_1-auc:0.99516
# [186]	validation_0-auc:0.99883	validation_1-auc:0.99514
# [188]	validation_0-auc:0.99884	validation_1-auc:0.99515
# [190]	validation_0-auc:0.99886	validation_1-auc:0.99518
# [192]	validation_0-auc:0.99887	validation_1-auc:0.99518
# [194]	validation_0-auc:0.99887	validation_1-auc:0.99516
# [196]	validation_0-auc:0.99889	validation_1-auc:0.99518
# [198]	validation_0-auc:0.99889	validation_1-auc:0.99522
# [200]	validation_0-auc:0.99890	validation_1-auc:0.99522
# [202]	validation_0-auc:0.99891	validation_1-auc:0.99524
# [204]	validation_0-auc:0.99891	validation_1-auc:0.99524
# [206]	validation_0-auc:0.99891	validation_1-auc:0.99525
# [208]	validation_0-auc:0.99892	validation_1-auc:0.99526
# [210]	validation_0-auc:0.99893	validation_1-auc:0.99526
# [212]	validation_0-auc:0.99893	validation_1-auc:0.99527
# [214]	validation_0-auc:0.99894	validation_1-auc:0.99531
# [216]	validation_0-auc:0.99894	validation_1-auc:0.99530
# [218]	validation_0-auc:0.99895	validation_1-auc:0.99532
# [220]	validation_0-auc:0.99895	validation_1-auc:0.99532
# [222]	validation_0-auc:0.99895	validation_1-auc:0.99534
# [224]	validation_0-auc:0.99896	validation_1-auc:0.99534
# [226]	validation_0-auc:0.99897	validation_1-auc:0.99532
# [228]	validation_0-auc:0.99897	validation_1-auc:0.99532
# [230]	validation_0-auc:0.99898	validation_1-auc:0.99534
# [232]	validation_0-auc:0.99898	validation_1-auc:0.99534
# [234]	validation_0-auc:0.99899	validation_1-auc:0.99535
# [236]	validation_0-auc:0.99899	validation_1-auc:0.99536
# [238]	validation_0-auc:0.99899	validation_1-auc:0.99536
# [240]	validation_0-auc:0.99900	validation_1-auc:0.99535
# [242]	validation_0-auc:0.99900	validation_1-auc:0.99536
# [244]	validation_0-auc:0.99901	validation_1-auc:0.99537
# [246]	validation_0-auc:0.99901	validation_1-auc:0.99540
# [248]	validation_0-auc:0.99902	validation_1-auc:0.99540
# [250]	validation_0-auc:0.99902	validation_1-auc:0.99540
# [252]	validation_0-auc:0.99902	validation_1-auc:0.99541
# [254]	validation_0-auc:0.99903	validation_1-auc:0.99542
# [256]	validation_0-auc:0.99903	validation_1-auc:0.99544
# [258]	validation_0-auc:0.99903	validation_1-auc:0.99545
# [260]	validation_0-auc:0.99904	validation_1-auc:0.99545
# [262]	validation_0-auc:0.99904	validation_1-auc:0.99545
# [264]	validation_0-auc:0.99904	validation_1-auc:0.99547
# [266]	validation_0-auc:0.99904	validation_1-auc:0.99547
# [268]	validation_0-auc:0.99904	validation_1-auc:0.99546
# [270]	validation_0-auc:0.99905	validation_1-auc:0.99547
# [272]	validation_0-auc:0.99905	validation_1-auc:0.99547
# [274]	validation_0-auc:0.99900	validation_1-auc:0.99546
# [276]	validation_0-auc:0.99900	validation_1-auc:0.99548
# [278]	validation_0-auc:0.99900	validation_1-auc:0.99548
# [280]	validation_0-auc:0.99900	validation_1-auc:0.99546
# [282]	validation_0-auc:0.99901	validation_1-auc:0.99547
# [284]	validation_0-auc:0.99901	validation_1-auc:0.99547
# [286]	validation_0-auc:0.99901	validation_1-auc:0.99549
# [288]	validation_0-auc:0.99901	validation_1-auc:0.99549
# [290]	validation_0-auc:0.99902	validation_1-auc:0.99550
# [292]	validation_0-auc:0.99902	validation_1-auc:0.99552
# [294]	validation_0-auc:0.99902	validation_1-auc:0.99552
# [296]	validation_0-auc:0.99902	validation_1-auc:0.99551
# [298]	validation_0-auc:0.99902	validation_1-auc:0.99553
# [300]	validation_0-auc:0.99981	validation_1-auc:0.99551
# [302]	validation_0-auc:0.99984	validation_1-auc:0.99553
# [304]	validation_0-auc:0.99985	validation_1-auc:0.99553
# [306]	validation_0-auc:0.99985	validation_1-auc:0.99554
# [308]	validation_0-auc:0.99986	validation_1-auc:0.99553
# [310]	validation_0-auc:0.99986	validation_1-auc:0.99553
# [312]	validation_0-auc:0.99986	validation_1-auc:0.99554
# [314]	validation_0-auc:0.99986	validation_1-auc:0.99555
# [316]	validation_0-auc:0.99986	validation_1-auc:0.99555
# [318]	validation_0-auc:0.99987	validation_1-auc:0.99554
# [320]	validation_0-auc:0.99987	validation_1-auc:0.99554
# [322]	validation_0-auc:0.99988	validation_1-auc:0.99557
# [324]	validation_0-auc:0.99988	validation_1-auc:0.99558
# [326]	validation_0-auc:0.99988	validation_1-auc:0.99557
# [328]	validation_0-auc:0.99989	validation_1-auc:0.99560
# [330]	validation_0-auc:0.99989	validation_1-auc:0.99561
# [332]	validation_0-auc:0.99989	validation_1-auc:0.99561
# [334]	validation_0-auc:0.99989	validation_1-auc:0.99561
# [336]	validation_0-auc:0.99989	validation_1-auc:0.99562
# [338]	validation_0-auc:0.99989	validation_1-auc:0.99563
# [340]	validation_0-auc:0.99989	validation_1-auc:0.99563
# [342]	validation_0-auc:0.99990	validation_1-auc:0.99563
# [344]	validation_0-auc:0.99990	validation_1-auc:0.99565
# [346]	validation_0-auc:0.99990	validation_1-auc:0.99565
# [348]	validation_0-auc:0.99990	validation_1-auc:0.99565
# [350]	validation_0-auc:0.99990	validation_1-auc:0.99566
# [352]	validation_0-auc:0.99990	validation_1-auc:0.99566
# [354]	validation_0-auc:0.99990	validation_1-auc:0.99567
# [356]	validation_0-auc:0.99990	validation_1-auc:0.99567
# [358]	validation_0-auc:0.99990	validation_1-auc:0.99567
# [360]	validation_0-auc:0.99991	validation_1-auc:0.99567
# [362]	validation_0-auc:0.99991	validation_1-auc:0.99567
# [364]	validation_0-auc:0.99991	validation_1-auc:0.99569
# [366]	validation_0-auc:0.99991	validation_1-auc:0.99569
# [368]	validation_0-auc:0.99991	validation_1-auc:0.99569
# [370]	validation_0-auc:0.99991	validation_1-auc:0.99568
# [372]	validation_0-auc:0.99991	validation_1-auc:0.99568
# [374]	validation_0-auc:0.99991	validation_1-auc:0.99571
# [376]	validation_0-auc:0.99991	validation_1-auc:0.99572
# [378]	validation_0-auc:0.99991	validation_1-auc:0.99573
# [380]	validation_0-auc:0.99991	validation_1-auc:0.99574
# [382]	validation_0-auc:0.99991	validation_1-auc:0.99575
# [384]	validation_0-auc:0.99991	validation_1-auc:0.99574
# [386]	validation_0-auc:0.99991	validation_1-auc:0.99574
# [388]	validation_0-auc:0.99991	validation_1-auc:0.99576
# [390]	validation_0-auc:0.99992	validation_1-auc:0.99575
# [392]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [394]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [396]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [398]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [400]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [402]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [404]	validation_0-auc:0.99992	validation_1-auc:0.99576
# [406]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [408]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [410]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [412]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [414]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [416]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [418]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [420]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [422]	validation_0-auc:0.99992	validation_1-auc:0.99577
# [424]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [426]	validation_0-auc:0.99992	validation_1-auc:0.99578
# [428]	validation_0-auc:0.99992	validation_1-auc:0.99579
# [430]	validation_0-auc:0.99992	validation_1-auc:0.99580
# [432]	validation_0-auc:0.99992	validation_1-auc:0.99579
# [434]	validation_0-auc:0.99992	validation_1-auc:0.99580
# [436]	validation_0-auc:0.99993	validation_1-auc:0.99579
# [438]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [440]	validation_0-auc:0.99993	validation_1-auc:0.99578
# [442]	validation_0-auc:0.99993	validation_1-auc:0.99579
# [444]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [446]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [448]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [450]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [452]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [454]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [456]	validation_0-auc:0.99993	validation_1-auc:0.99580
# [458]	validation_0-auc:0.99993	validation_1-auc:0.99581
# [460]	validation_0-auc:0.99993	validation_1-auc:0.99579
# [462]	validation_0-auc:0.99993	validation_1-auc:0.99581
# [464]	validation_0-auc:0.99993	validation_1-auc:0.99581
# [466]	validation_0-auc:0.99993	validation_1-auc:0.99581
# [468]	validation_0-auc:0.99993	validation_1-auc:0.99582
# [470]	validation_0-auc:0.99993	validation_1-auc:0.99583
# [472]	validation_0-auc:0.99993	validation_1-auc:0.99583
# [474]	validation_0-auc:0.99993	validation_1-auc:0.99582
# [476]	validation_0-auc:0.99993	validation_1-auc:0.99582
# [478]	validation_0-auc:0.99993	validation_1-auc:0.99581
# [480]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [482]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [484]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [486]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [488]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [490]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [492]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [494]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [496]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [498]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [500]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [502]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [504]	validation_0-auc:0.99994	validation_1-auc:0.99586
# [506]	validation_0-auc:0.99994	validation_1-auc:0.99584
# [508]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [510]	validation_0-auc:0.99994	validation_1-auc:0.99585
# [512]	validation_0-auc:0.99994	validation_1-auc:0.99584
# [514]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [516]	validation_0-auc:0.99994	validation_1-auc:0.99584
# [518]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [520]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [522]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [524]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [526]	validation_0-auc:0.99994	validation_1-auc:0.99583
# [528]	validation_0-auc:0.99994	validation_1-auc:0.99584
# [0]	validation_0-auc:0.99073	validation_1-auc:0.97584
# [2]	validation_0-auc:0.99812	validation_1-auc:0.98541
# [4]	validation_0-auc:0.99798	validation_1-auc:0.98560
# [6]	validation_0-auc:0.99781	validation_1-auc:0.98564
# [8]	validation_0-auc:0.99782	validation_1-auc:0.98568
# [10]	validation_0-auc:0.99781	validation_1-auc:0.98563
# [12]	validation_0-auc:0.99778	validation_1-auc:0.98559
# [14]	validation_0-auc:0.99776	validation_1-auc:0.98548
# [16]	validation_0-auc:0.99778	validation_1-auc:0.98542
# [18]	validation_0-auc:0.99780	validation_1-auc:0.98546
# [20]	validation_0-auc:0.99793	validation_1-auc:0.98529
# [22]	validation_0-auc:0.99801	validation_1-auc:0.98524
# [24]	validation_0-auc:0.99805	validation_1-auc:0.98546
# [26]	validation_0-auc:0.99806	validation_1-auc:0.98534
# [28]	validation_0-auc:0.99821	validation_1-auc:0.98517
# [30]	validation_0-auc:0.99825	validation_1-auc:0.98515
# [32]	validation_0-auc:0.99828	validation_1-auc:0.98509
# [33]	validation_0-auc:0.99829	validation_1-auc:0.98506
# [0]	validation_0-auc:0.98652	validation_1-auc:0.98425
# [2]	validation_0-auc:0.99585	validation_1-auc:0.99278
# [4]	validation_0-auc:0.99561	validation_1-auc:0.99330
# [6]	validation_0-auc:0.99545	validation_1-auc:0.99346
# [8]	validation_0-auc:0.99580	validation_1-auc:0.99365
# [10]	validation_0-auc:0.99616	validation_1-auc:0.99332
# [12]	validation_0-auc:0.99615	validation_1-auc:0.99334
# [14]	validation_0-auc:0.99621	validation_1-auc:0.99333
# [16]	validation_0-auc:0.99628	validation_1-auc:0.99372
# [18]	validation_0-auc:0.99639	validation_1-auc:0.99379
# [20]	validation_0-auc:0.99637	validation_1-auc:0.99375
# [22]	validation_0-auc:0.99646	validation_1-auc:0.99374
# [24]	validation_0-auc:0.99668	validation_1-auc:0.99373
# [26]	validation_0-auc:0.99681	validation_1-auc:0.99358
# [28]	validation_0-auc:0.99683	validation_1-auc:0.99355
# [30]	validation_0-auc:0.99689	validation_1-auc:0.99355
# [32]	validation_0-auc:0.99692	validation_1-auc:0.99359
# [34]	validation_0-auc:0.99714	validation_1-auc:0.99383
# [36]	validation_0-auc:0.99717	validation_1-auc:0.99382
# [38]	validation_0-auc:0.99725	validation_1-auc:0.99381
# [40]	validation_0-auc:0.99731	validation_1-auc:0.99372
# [42]	validation_0-auc:0.99737	validation_1-auc:0.99395
# [44]	validation_0-auc:0.99744	validation_1-auc:0.99403
# [46]	validation_0-auc:0.99743	validation_1-auc:0.99401
# [48]	validation_0-auc:0.99747	validation_1-auc:0.99412
# [50]	validation_0-auc:0.99752	validation_1-auc:0.99410
# [52]	validation_0-auc:0.99756	validation_1-auc:0.99413
# [54]	validation_0-auc:0.99759	validation_1-auc:0.99412
# [56]	validation_0-auc:0.99760	validation_1-auc:0.99408
# [58]	validation_0-auc:0.99765	validation_1-auc:0.99406
# [60]	validation_0-auc:0.99766	validation_1-auc:0.99408
# [62]	validation_0-auc:0.99771	validation_1-auc:0.99407
# [64]	validation_0-auc:0.99776	validation_1-auc:0.99410
# [66]	validation_0-auc:0.99780	validation_1-auc:0.99413
# [68]	validation_0-auc:0.99784	validation_1-auc:0.99416
# [70]	validation_0-auc:0.99788	validation_1-auc:0.99420
# [72]	validation_0-auc:0.99791	validation_1-auc:0.99424
# [74]	validation_0-auc:0.99794	validation_1-auc:0.99422
# [76]	validation_0-auc:0.99798	validation_1-auc:0.99420
# [78]	validation_0-auc:0.99800	validation_1-auc:0.99417
# [80]	validation_0-auc:0.99803	validation_1-auc:0.99423
# [82]	validation_0-auc:0.99806	validation_1-auc:0.99424
# [84]	validation_0-auc:0.99808	validation_1-auc:0.99422
# [86]	validation_0-auc:0.99812	validation_1-auc:0.99430
# [88]	validation_0-auc:0.99815	validation_1-auc:0.99428
# [90]	validation_0-auc:0.99817	validation_1-auc:0.99428
# [92]	validation_0-auc:0.99818	validation_1-auc:0.99429
# [94]	validation_0-auc:0.99821	validation_1-auc:0.99430
# [96]	validation_0-auc:0.99823	validation_1-auc:0.99430
# [98]	validation_0-auc:0.99825	validation_1-auc:0.99431
# [100]	validation_0-auc:0.99827	validation_1-auc:0.99433
# [102]	validation_0-auc:0.99829	validation_1-auc:0.99436
# [104]	validation_0-auc:0.99831	validation_1-auc:0.99435
# [106]	validation_0-auc:0.99833	validation_1-auc:0.99435
# [108]	validation_0-auc:0.99836	validation_1-auc:0.99437
# [110]	validation_0-auc:0.99837	validation_1-auc:0.99437
# [112]	validation_0-auc:0.99840	validation_1-auc:0.99437
# [114]	validation_0-auc:0.99841	validation_1-auc:0.99436
# [116]	validation_0-auc:0.99843	validation_1-auc:0.99438
# [118]	validation_0-auc:0.99845	validation_1-auc:0.99444
# [120]	validation_0-auc:0.99847	validation_1-auc:0.99447
# [122]	validation_0-auc:0.99849	validation_1-auc:0.99448
# [124]	validation_0-auc:0.99850	validation_1-auc:0.99450
# [126]	validation_0-auc:0.99851	validation_1-auc:0.99451
# [128]	validation_0-auc:0.99852	validation_1-auc:0.99454
# [130]	validation_0-auc:0.99854	validation_1-auc:0.99454
# [132]	validation_0-auc:0.99855	validation_1-auc:0.99455
# [134]	validation_0-auc:0.99856	validation_1-auc:0.99455
# [136]	validation_0-auc:0.99858	validation_1-auc:0.99455
# [138]	validation_0-auc:0.99859	validation_1-auc:0.99458
# [140]	validation_0-auc:0.99860	validation_1-auc:0.99457
# [142]	validation_0-auc:0.99860	validation_1-auc:0.99458
# [144]	validation_0-auc:0.99861	validation_1-auc:0.99457
# [146]	validation_0-auc:0.99863	validation_1-auc:0.99458
# [148]	validation_0-auc:0.99864	validation_1-auc:0.99459
# [150]	validation_0-auc:0.99864	validation_1-auc:0.99460
# [152]	validation_0-auc:0.99865	validation_1-auc:0.99460
# [154]	validation_0-auc:0.99866	validation_1-auc:0.99461
# [156]	validation_0-auc:0.99867	validation_1-auc:0.99460
# [158]	validation_0-auc:0.99868	validation_1-auc:0.99458
# [160]	validation_0-auc:0.99868	validation_1-auc:0.99459
# [162]	validation_0-auc:0.99870	validation_1-auc:0.99459
# [164]	validation_0-auc:0.99870	validation_1-auc:0.99458
# [166]	validation_0-auc:0.99871	validation_1-auc:0.99461
# [168]	validation_0-auc:0.99872	validation_1-auc:0.99457
# [170]	validation_0-auc:0.99872	validation_1-auc:0.99457
# [172]	validation_0-auc:0.99873	validation_1-auc:0.99456
# [174]	validation_0-auc:0.99873	validation_1-auc:0.99459
# [176]	validation_0-auc:0.99874	validation_1-auc:0.99460
# [177]	validation_0-auc:0.99874	validation_1-auc:0.99460
# [0]	validation_0-auc:0.99072	validation_1-auc:0.97697
# [2]	validation_0-auc:0.99652	validation_1-auc:0.99029
# [4]	validation_0-auc:0.99669	validation_1-auc:0.99058
# [6]	validation_0-auc:0.99673	validation_1-auc:0.99065
# [8]	validation_0-auc:0.99681	validation_1-auc:0.99050
# [10]	validation_0-auc:0.99683	validation_1-auc:0.99039
# [12]	validation_0-auc:0.99706	validation_1-auc:0.99082
# [14]	validation_0-auc:0.99709	validation_1-auc:0.99079
# [16]	validation_0-auc:0.99702	validation_1-auc:0.99093
# [18]	validation_0-auc:0.99703	validation_1-auc:0.99095
# [20]	validation_0-auc:0.99702	validation_1-auc:0.99090
# [22]	validation_0-auc:0.99718	validation_1-auc:0.99096
# [24]	validation_0-auc:0.99719	validation_1-auc:0.99086
# [26]	validation_0-auc:0.99717	validation_1-auc:0.99080
# [28]	validation_0-auc:0.99720	validation_1-auc:0.99072
# [30]	validation_0-auc:0.99758	validation_1-auc:0.99109
# [32]	validation_0-auc:0.99758	validation_1-auc:0.99102
# [34]	validation_0-auc:0.99768	validation_1-auc:0.99109
# [36]	validation_0-auc:0.99773	validation_1-auc:0.99106
# [38]	validation_0-auc:0.99781	validation_1-auc:0.99106
# [40]	validation_0-auc:0.99780	validation_1-auc:0.99104
# [42]	validation_0-auc:0.99783	validation_1-auc:0.99119
# [44]	validation_0-auc:0.99786	validation_1-auc:0.99123
# [46]	validation_0-auc:0.99786	validation_1-auc:0.99123
# [48]	validation_0-auc:0.99789	validation_1-auc:0.99130
# [50]	validation_0-auc:0.99790	validation_1-auc:0.99130
# [52]	validation_0-auc:0.99790	validation_1-auc:0.99126
# [54]	validation_0-auc:0.99793	validation_1-auc:0.99123
# [56]	validation_0-auc:0.99797	validation_1-auc:0.99123
# [58]	validation_0-auc:0.99801	validation_1-auc:0.99119
# [60]	validation_0-auc:0.99803	validation_1-auc:0.99125
# [62]	validation_0-auc:0.99805	validation_1-auc:0.99125
# [64]	validation_0-auc:0.99806	validation_1-auc:0.99129
# [66]	validation_0-auc:0.99807	validation_1-auc:0.99132
# [68]	validation_0-auc:0.99808	validation_1-auc:0.99131
# [70]	validation_0-auc:0.99810	validation_1-auc:0.99133
# [72]	validation_0-auc:0.99816	validation_1-auc:0.99131
# [74]	validation_0-auc:0.99818	validation_1-auc:0.99129
# [76]	validation_0-auc:0.99818	validation_1-auc:0.99131
# [78]	validation_0-auc:0.99819	validation_1-auc:0.99135
# [80]	validation_0-auc:0.99821	validation_1-auc:0.99138
# [82]	validation_0-auc:0.99822	validation_1-auc:0.99135
# [84]	validation_0-auc:0.99822	validation_1-auc:0.99135
# [86]	validation_0-auc:0.99824	validation_1-auc:0.99137
# [88]	validation_0-auc:0.99826	validation_1-auc:0.99139
# [90]	validation_0-auc:0.99828	validation_1-auc:0.99140
# [92]	validation_0-auc:0.99829	validation_1-auc:0.99139
# [94]	validation_0-auc:0.99830	validation_1-auc:0.99143
# [96]	validation_0-auc:0.99831	validation_1-auc:0.99147
# [98]	validation_0-auc:0.99833	validation_1-auc:0.99146
# [100]	validation_0-auc:0.99833	validation_1-auc:0.99148
# [102]	validation_0-auc:0.99834	validation_1-auc:0.99144
# [104]	validation_0-auc:0.99837	validation_1-auc:0.99142
# [106]	validation_0-auc:0.99837	validation_1-auc:0.99147
# [108]	validation_0-auc:0.99839	validation_1-auc:0.99154
# [110]	validation_0-auc:0.99840	validation_1-auc:0.99154
# [112]	validation_0-auc:0.99841	validation_1-auc:0.99161
# [114]	validation_0-auc:0.99841	validation_1-auc:0.99159
# [116]	validation_0-auc:0.99843	validation_1-auc:0.99164
# [118]	validation_0-auc:0.99844	validation_1-auc:0.99161
# [120]	validation_0-auc:0.99846	validation_1-auc:0.99161
# [122]	validation_0-auc:0.99847	validation_1-auc:0.99163
# [124]	validation_0-auc:0.99848	validation_1-auc:0.99165
# [126]	validation_0-auc:0.99849	validation_1-auc:0.99165
# [128]	validation_0-auc:0.99850	validation_1-auc:0.99166
# [130]	validation_0-auc:0.99850	validation_1-auc:0.99169
# [132]	validation_0-auc:0.99851	validation_1-auc:0.99171
# [134]	validation_0-auc:0.99853	validation_1-auc:0.99174
# [136]	validation_0-auc:0.99853	validation_1-auc:0.99173
# [138]	validation_0-auc:0.99855	validation_1-auc:0.99177
# [140]	validation_0-auc:0.99856	validation_1-auc:0.99179
# [142]	validation_0-auc:0.99857	validation_1-auc:0.99186
# [144]	validation_0-auc:0.99857	validation_1-auc:0.99186
# [146]	validation_0-auc:0.99858	validation_1-auc:0.99185
# [148]	validation_0-auc:0.99859	validation_1-auc:0.99187
# [150]	validation_0-auc:0.99860	validation_1-auc:0.99187
# [152]	validation_0-auc:0.99860	validation_1-auc:0.99192
# [154]	validation_0-auc:0.99863	validation_1-auc:0.99199
# [156]	validation_0-auc:0.99864	validation_1-auc:0.99200
# [158]	validation_0-auc:0.99864	validation_1-auc:0.99200
# [160]	validation_0-auc:0.99865	validation_1-auc:0.99201
# [162]	validation_0-auc:0.99867	validation_1-auc:0.99202
# [164]	validation_0-auc:0.99868	validation_1-auc:0.99204
# [166]	validation_0-auc:0.99868	validation_1-auc:0.99207
# [168]	validation_0-auc:0.99869	validation_1-auc:0.99206
# [170]	validation_0-auc:0.99870	validation_1-auc:0.99208
# [172]	validation_0-auc:0.99871	validation_1-auc:0.99207
# [174]	validation_0-auc:0.99871	validation_1-auc:0.99210
# [176]	validation_0-auc:0.99872	validation_1-auc:0.99208
# [178]	validation_0-auc:0.99872	validation_1-auc:0.99206
# [180]	validation_0-auc:0.99873	validation_1-auc:0.99206
# [182]	validation_0-auc:0.99873	validation_1-auc:0.99208
# [184]	validation_0-auc:0.99874	validation_1-auc:0.99209
# [186]	validation_0-auc:0.99875	validation_1-auc:0.99211
# [188]	validation_0-auc:0.99875	validation_1-auc:0.99212
# [190]	validation_0-auc:0.99876	validation_1-auc:0.99212
# [192]	validation_0-auc:0.99877	validation_1-auc:0.99211
# [194]	validation_0-auc:0.99877	validation_1-auc:0.99212
# [196]	validation_0-auc:0.99878	validation_1-auc:0.99217
# [198]	validation_0-auc:0.99878	validation_1-auc:0.99213
# [200]	validation_0-auc:0.99879	validation_1-auc:0.99217
# [202]	validation_0-auc:0.99879	validation_1-auc:0.99218
# [204]	validation_0-auc:0.99880	validation_1-auc:0.99216
# [206]	validation_0-auc:0.99881	validation_1-auc:0.99217
# [208]	validation_0-auc:0.99881	validation_1-auc:0.99218
# [210]	validation_0-auc:0.99882	validation_1-auc:0.99220
# [212]	validation_0-auc:0.99883	validation_1-auc:0.99219
# [214]	validation_0-auc:0.99883	validation_1-auc:0.99222
# [216]	validation_0-auc:0.99884	validation_1-auc:0.99223
# [218]	validation_0-auc:0.99884	validation_1-auc:0.99225
# [220]	validation_0-auc:0.99885	validation_1-auc:0.99223
# [222]	validation_0-auc:0.99885	validation_1-auc:0.99224
# [224]	validation_0-auc:0.99886	validation_1-auc:0.99223
# [226]	validation_0-auc:0.99886	validation_1-auc:0.99226
# [228]	validation_0-auc:0.99887	validation_1-auc:0.99226
# [230]	validation_0-auc:0.99887	validation_1-auc:0.99226
# [232]	validation_0-auc:0.99888	validation_1-auc:0.99225
# [234]	validation_0-auc:0.99888	validation_1-auc:0.99225
# [236]	validation_0-auc:0.99889	validation_1-auc:0.99227
# [238]	validation_0-auc:0.99890	validation_1-auc:0.99227
# [240]	validation_0-auc:0.99890	validation_1-auc:0.99231
# [242]	validation_0-auc:0.99891	validation_1-auc:0.99229
# [244]	validation_0-auc:0.99891	validation_1-auc:0.99233
# [246]	validation_0-auc:0.99892	validation_1-auc:0.99233
# [248]	validation_0-auc:0.99893	validation_1-auc:0.99230
# [250]	validation_0-auc:0.99893	validation_1-auc:0.99230
# [252]	validation_0-auc:0.99894	validation_1-auc:0.99233
# [254]	validation_0-auc:0.99894	validation_1-auc:0.99235
# [256]	validation_0-auc:0.99894	validation_1-auc:0.99235
# [258]	validation_0-auc:0.99895	validation_1-auc:0.99236
# [260]	validation_0-auc:0.99895	validation_1-auc:0.99237
# [262]	validation_0-auc:0.99896	validation_1-auc:0.99238
# [264]	validation_0-auc:0.99896	validation_1-auc:0.99237
# [266]	validation_0-auc:0.99897	validation_1-auc:0.99238
# [268]	validation_0-auc:0.99897	validation_1-auc:0.99239
# [270]	validation_0-auc:0.99898	validation_1-auc:0.99240
# [272]	validation_0-auc:0.99898	validation_1-auc:0.99239
# [274]	validation_0-auc:0.99893	validation_1-auc:0.99242
# [276]	validation_0-auc:0.99894	validation_1-auc:0.99246
# [278]	validation_0-auc:0.99894	validation_1-auc:0.99248
# [280]	validation_0-auc:0.99894	validation_1-auc:0.99247
# [282]	validation_0-auc:0.99895	validation_1-auc:0.99249
# [284]	validation_0-auc:0.99895	validation_1-auc:0.99249
# [286]	validation_0-auc:0.99895	validation_1-auc:0.99248
# [288]	validation_0-auc:0.99895	validation_1-auc:0.99252
# [290]	validation_0-auc:0.99896	validation_1-auc:0.99251
# [292]	validation_0-auc:0.99896	validation_1-auc:0.99250
# [294]	validation_0-auc:0.99896	validation_1-auc:0.99248
# [296]	validation_0-auc:0.99896	validation_1-auc:0.99248
# [298]	validation_0-auc:0.99897	validation_1-auc:0.99251
# [300]	validation_0-auc:0.99977	validation_1-auc:0.99248
# [302]	validation_0-auc:0.99980	validation_1-auc:0.99253
# [304]	validation_0-auc:0.99981	validation_1-auc:0.99253
# [306]	validation_0-auc:0.99981	validation_1-auc:0.99254
# [308]	validation_0-auc:0.99983	validation_1-auc:0.99256
# [310]	validation_0-auc:0.99984	validation_1-auc:0.99253
# [312]	validation_0-auc:0.99984	validation_1-auc:0.99254
# [314]	validation_0-auc:0.99984	validation_1-auc:0.99255
# [316]	validation_0-auc:0.99985	validation_1-auc:0.99256
# [318]	validation_0-auc:0.99985	validation_1-auc:0.99258
# [320]	validation_0-auc:0.99985	validation_1-auc:0.99252
# [322]	validation_0-auc:0.99986	validation_1-auc:0.99255
# [324]	validation_0-auc:0.99986	validation_1-auc:0.99255
# [326]	validation_0-auc:0.99986	validation_1-auc:0.99258
# [328]	validation_0-auc:0.99986	validation_1-auc:0.99260
# [330]	validation_0-auc:0.99987	validation_1-auc:0.99258
# [332]	validation_0-auc:0.99987	validation_1-auc:0.99259
# [334]	validation_0-auc:0.99987	validation_1-auc:0.99262
# [336]	validation_0-auc:0.99987	validation_1-auc:0.99262
# [338]	validation_0-auc:0.99988	validation_1-auc:0.99263
# [340]	validation_0-auc:0.99988	validation_1-auc:0.99263
# [342]	validation_0-auc:0.99988	validation_1-auc:0.99265
# [344]	validation_0-auc:0.99988	validation_1-auc:0.99264
# [346]	validation_0-auc:0.99988	validation_1-auc:0.99264
# [348]	validation_0-auc:0.99988	validation_1-auc:0.99263
# [350]	validation_0-auc:0.99989	validation_1-auc:0.99262
# [352]	validation_0-auc:0.99989	validation_1-auc:0.99260
# [354]	validation_0-auc:0.99989	validation_1-auc:0.99261
# [356]	validation_0-auc:0.99989	validation_1-auc:0.99261
# [358]	validation_0-auc:0.99989	validation_1-auc:0.99263
# [360]	validation_0-auc:0.99989	validation_1-auc:0.99262
# [362]	validation_0-auc:0.99990	validation_1-auc:0.99261
# [364]	validation_0-auc:0.99990	validation_1-auc:0.99264
# [366]	validation_0-auc:0.99990	validation_1-auc:0.99264
# [367]	validation_0-auc:0.99990	validation_1-auc:0.99264
# [0]	validation_0-auc:0.98828	validation_1-auc:0.97912
# [2]	validation_0-auc:0.99717	validation_1-auc:0.98475
# [4]	validation_0-auc:0.99704	validation_1-auc:0.98544
# [6]	validation_0-auc:0.99690	validation_1-auc:0.98572
# [8]	validation_0-auc:0.99679	validation_1-auc:0.98582
# [10]	validation_0-auc:0.99672	validation_1-auc:0.98580
# [12]	validation_0-auc:0.99668	validation_1-auc:0.98907
# [14]	validation_0-auc:0.99669	validation_1-auc:0.98899
# [16]	validation_0-auc:0.99665	validation_1-auc:0.98891
# [18]	validation_0-auc:0.99677	validation_1-auc:0.98920
# [20]	validation_0-auc:0.99703	validation_1-auc:0.98953
# [22]	validation_0-auc:0.99702	validation_1-auc:0.98961
# [24]	validation_0-auc:0.99707	validation_1-auc:0.98959
# [26]	validation_0-auc:0.99708	validation_1-auc:0.98957
# [28]	validation_0-auc:0.99715	validation_1-auc:0.98967
# [30]	validation_0-auc:0.99713	validation_1-auc:0.98972
# [32]	validation_0-auc:0.99715	validation_1-auc:0.98970
# [34]	validation_0-auc:0.99729	validation_1-auc:0.98981
# [36]	validation_0-auc:0.99739	validation_1-auc:0.98995
# [38]	validation_0-auc:0.99745	validation_1-auc:0.99001
# [40]	validation_0-auc:0.99750	validation_1-auc:0.99004
# [42]	validation_0-auc:0.99754	validation_1-auc:0.99001
# [44]	validation_0-auc:0.99763	validation_1-auc:0.99006
# [46]	validation_0-auc:0.99765	validation_1-auc:0.99009
# [48]	validation_0-auc:0.99766	validation_1-auc:0.99009
# [50]	validation_0-auc:0.99770	validation_1-auc:0.99020
# [52]	validation_0-auc:0.99772	validation_1-auc:0.99019
# [54]	validation_0-auc:0.99775	validation_1-auc:0.99018
# [56]	validation_0-auc:0.99775	validation_1-auc:0.99015
# [58]	validation_0-auc:0.99779	validation_1-auc:0.99021
# [60]	validation_0-auc:0.99782	validation_1-auc:0.99017
# [62]	validation_0-auc:0.99784	validation_1-auc:0.99014
# [64]	validation_0-auc:0.99788	validation_1-auc:0.99012
# [66]	validation_0-auc:0.99791	validation_1-auc:0.99010
# [68]	validation_0-auc:0.99793	validation_1-auc:0.99011
# [70]	validation_0-auc:0.99794	validation_1-auc:0.99012
# [72]	validation_0-auc:0.99796	validation_1-auc:0.99012
# [74]	validation_0-auc:0.99798	validation_1-auc:0.99010
# [76]	validation_0-auc:0.99798	validation_1-auc:0.99009
# [78]	validation_0-auc:0.99799	validation_1-auc:0.99011
# [80]	validation_0-auc:0.99800	validation_1-auc:0.99009
# [82]	validation_0-auc:0.99802	validation_1-auc:0.99006
# [83]	validation_0-auc:0.99803	validation_1-auc:0.99007
# 1it [01:08, 68.03s/it]
# 1fold f1: 0.8425922323184983
# [0]	validation_0-auc:0.98954	validation_1-auc:0.98899
# [2]	validation_0-auc:0.99645	validation_1-auc:0.99347
# [4]	validation_0-auc:0.99628	validation_1-auc:0.99405
# [6]	validation_0-auc:0.99632	validation_1-auc:0.99403
# [8]	validation_0-auc:0.99647	validation_1-auc:0.99415
# [10]	validation_0-auc:0.99647	validation_1-auc:0.99410
# [12]	validation_0-auc:0.99656	validation_1-auc:0.99412
# [14]	validation_0-auc:0.99665	validation_1-auc:0.99411
# [16]	validation_0-auc:0.99663	validation_1-auc:0.99403
# [18]	validation_0-auc:0.99662	validation_1-auc:0.99401
# [20]	validation_0-auc:0.99664	validation_1-auc:0.99400
# [22]	validation_0-auc:0.99680	validation_1-auc:0.99405
# [24]	validation_0-auc:0.99682	validation_1-auc:0.99412
# [26]	validation_0-auc:0.99686	validation_1-auc:0.99416
# [28]	validation_0-auc:0.99693	validation_1-auc:0.99405
# [30]	validation_0-auc:0.99693	validation_1-auc:0.99407
# [32]	validation_0-auc:0.99692	validation_1-auc:0.99403
# [34]	validation_0-auc:0.99711	validation_1-auc:0.99423
# [36]	validation_0-auc:0.99717	validation_1-auc:0.99436
# [38]	validation_0-auc:0.99722	validation_1-auc:0.99439
# [40]	validation_0-auc:0.99721	validation_1-auc:0.99439
# [42]	validation_0-auc:0.99723	validation_1-auc:0.99443
# [44]	validation_0-auc:0.99726	validation_1-auc:0.99440
# [46]	validation_0-auc:0.99733	validation_1-auc:0.99443
# [48]	validation_0-auc:0.99731	validation_1-auc:0.99443
# [50]	validation_0-auc:0.99739	validation_1-auc:0.99438
# [52]	validation_0-auc:0.99740	validation_1-auc:0.99438
# [54]	validation_0-auc:0.99740	validation_1-auc:0.99435
# [56]	validation_0-auc:0.99748	validation_1-auc:0.99447
# [58]	validation_0-auc:0.99751	validation_1-auc:0.99447
# [60]	validation_0-auc:0.99755	validation_1-auc:0.99450
# [62]	validation_0-auc:0.99757	validation_1-auc:0.99460
# [64]	validation_0-auc:0.99759	validation_1-auc:0.99457
# [66]	validation_0-auc:0.99769	validation_1-auc:0.99455
# [68]	validation_0-auc:0.99770	validation_1-auc:0.99458
# [70]	validation_0-auc:0.99778	validation_1-auc:0.99455
# [72]	validation_0-auc:0.99780	validation_1-auc:0.99454
# [74]	validation_0-auc:0.99785	validation_1-auc:0.99466
# [76]	validation_0-auc:0.99789	validation_1-auc:0.99471
# [78]	validation_0-auc:0.99791	validation_1-auc:0.99469
# [80]	validation_0-auc:0.99793	validation_1-auc:0.99469
# [82]	validation_0-auc:0.99795	validation_1-auc:0.99475
# [84]	validation_0-auc:0.99796	validation_1-auc:0.99471
# [86]	validation_0-auc:0.99800	validation_1-auc:0.99472
# [88]	validation_0-auc:0.99803	validation_1-auc:0.99477
# [90]	validation_0-auc:0.99805	validation_1-auc:0.99475
# [92]	validation_0-auc:0.99807	validation_1-auc:0.99480
# [94]	validation_0-auc:0.99810	validation_1-auc:0.99483
# [96]	validation_0-auc:0.99812	validation_1-auc:0.99479
# [98]	validation_0-auc:0.99815	validation_1-auc:0.99478
# [100]	validation_0-auc:0.99817	validation_1-auc:0.99478
# [102]	validation_0-auc:0.99818	validation_1-auc:0.99483
# [104]	validation_0-auc:0.99819	validation_1-auc:0.99482
# [106]	validation_0-auc:0.99820	validation_1-auc:0.99482
# [108]	validation_0-auc:0.99829	validation_1-auc:0.99487
# [110]	validation_0-auc:0.99831	validation_1-auc:0.99484
# [112]	validation_0-auc:0.99833	validation_1-auc:0.99485
# [114]	validation_0-auc:0.99836	validation_1-auc:0.99484
# [116]	validation_0-auc:0.99837	validation_1-auc:0.99481
# [118]	validation_0-auc:0.99839	validation_1-auc:0.99485
# [120]	validation_0-auc:0.99841	validation_1-auc:0.99482
# [122]	validation_0-auc:0.99842	validation_1-auc:0.99484
# [124]	validation_0-auc:0.99843	validation_1-auc:0.99481
# [126]	validation_0-auc:0.99844	validation_1-auc:0.99482
# [128]	validation_0-auc:0.99846	validation_1-auc:0.99482
# [130]	validation_0-auc:0.99848	validation_1-auc:0.99481
# [132]	validation_0-auc:0.99849	validation_1-auc:0.99478
# [133]	validation_0-auc:0.99849	validation_1-auc:0.99477
# [0]	validation_0-auc:0.99244	validation_1-auc:0.97201
# [2]	validation_0-auc:0.99748	validation_1-auc:0.99119
# [4]	validation_0-auc:0.99760	validation_1-auc:0.99162
# [6]	validation_0-auc:0.99742	validation_1-auc:0.99176
# [8]	validation_0-auc:0.99742	validation_1-auc:0.99200
# [10]	validation_0-auc:0.99742	validation_1-auc:0.99178
# [12]	validation_0-auc:0.99744	validation_1-auc:0.99181
# [14]	validation_0-auc:0.99743	validation_1-auc:0.99177
# [16]	validation_0-auc:0.99746	validation_1-auc:0.99184
# [18]	validation_0-auc:0.99756	validation_1-auc:0.99174
# [20]	validation_0-auc:0.99755	validation_1-auc:0.99175
# [22]	validation_0-auc:0.99758	validation_1-auc:0.99177
# [24]	validation_0-auc:0.99764	validation_1-auc:0.99175
# [26]	validation_0-auc:0.99769	validation_1-auc:0.99186
# [28]	validation_0-auc:0.99776	validation_1-auc:0.99183
# [30]	validation_0-auc:0.99777	validation_1-auc:0.99184
# [32]	validation_0-auc:0.99776	validation_1-auc:0.99185
# [0]	validation_0-auc:0.98763	validation_1-auc:0.98743
# [2]	validation_0-auc:0.99592	validation_1-auc:0.99073
# [4]	validation_0-auc:0.99575	validation_1-auc:0.99084
# [6]	validation_0-auc:0.99585	validation_1-auc:0.99106
# [8]	validation_0-auc:0.99583	validation_1-auc:0.99104
# [10]	validation_0-auc:0.99581	validation_1-auc:0.99101
# [12]	validation_0-auc:0.99580	validation_1-auc:0.99100
# [14]	validation_0-auc:0.99579	validation_1-auc:0.99101
# [16]	validation_0-auc:0.99579	validation_1-auc:0.99111
# [18]	validation_0-auc:0.99585	validation_1-auc:0.99114
# [20]	validation_0-auc:0.99584	validation_1-auc:0.99115
# [22]	validation_0-auc:0.99595	validation_1-auc:0.99130
# [24]	validation_0-auc:0.99595	validation_1-auc:0.99134
# [26]	validation_0-auc:0.99625	validation_1-auc:0.99180
# [28]	validation_0-auc:0.99639	validation_1-auc:0.99180
# [30]	validation_0-auc:0.99642	validation_1-auc:0.99181
# [32]	validation_0-auc:0.99645	validation_1-auc:0.99176
# [34]	validation_0-auc:0.99653	validation_1-auc:0.99197
# [36]	validation_0-auc:0.99661	validation_1-auc:0.99208
# [38]	validation_0-auc:0.99666	validation_1-auc:0.99200
# [40]	validation_0-auc:0.99665	validation_1-auc:0.99196
# [42]	validation_0-auc:0.99665	validation_1-auc:0.99201
# [44]	validation_0-auc:0.99667	validation_1-auc:0.99202
# [46]	validation_0-auc:0.99683	validation_1-auc:0.99189
# [48]	validation_0-auc:0.99685	validation_1-auc:0.99184
# [50]	validation_0-auc:0.99695	validation_1-auc:0.99180
# [52]	validation_0-auc:0.99695	validation_1-auc:0.99180
# [54]	validation_0-auc:0.99699	validation_1-auc:0.99181
# [56]	validation_0-auc:0.99704	validation_1-auc:0.99177
# [58]	validation_0-auc:0.99709	validation_1-auc:0.99178
# [60]	validation_0-auc:0.99715	validation_1-auc:0.99177
# [61]	validation_0-auc:0.99718	validation_1-auc:0.99177
# [0]	validation_0-auc:0.98652	validation_1-auc:0.98515
# [2]	validation_0-auc:0.99671	validation_1-auc:0.98888
# [4]	validation_0-auc:0.99648	validation_1-auc:0.98933
# [6]	validation_0-auc:0.99650	validation_1-auc:0.99002
# [8]	validation_0-auc:0.99639	validation_1-auc:0.99010
# [10]	validation_0-auc:0.99628	validation_1-auc:0.99005
# [12]	validation_0-auc:0.99625	validation_1-auc:0.98991
# [14]	validation_0-auc:0.99621	validation_1-auc:0.98993
# [16]	validation_0-auc:0.99626	validation_1-auc:0.99002
# [18]	validation_0-auc:0.99624	validation_1-auc:0.99027
# [20]	validation_0-auc:0.99633	validation_1-auc:0.99033
# [22]	validation_0-auc:0.99634	validation_1-auc:0.99042
# [24]	validation_0-auc:0.99634	validation_1-auc:0.99051
# [26]	validation_0-auc:0.99639	validation_1-auc:0.99066
# [28]	validation_0-auc:0.99647	validation_1-auc:0.99073
# [30]	validation_0-auc:0.99646	validation_1-auc:0.99064
# [32]	validation_0-auc:0.99646	validation_1-auc:0.99063
# [34]	validation_0-auc:0.99672	validation_1-auc:0.99378
# [36]	validation_0-auc:0.99674	validation_1-auc:0.99391
# [38]	validation_0-auc:0.99676	validation_1-auc:0.99385
# [40]	validation_0-auc:0.99678	validation_1-auc:0.99389
# [42]	validation_0-auc:0.99684	validation_1-auc:0.99396
# [44]	validation_0-auc:0.99685	validation_1-auc:0.99396
# [46]	validation_0-auc:0.99688	validation_1-auc:0.99400
# [48]	validation_0-auc:0.99692	validation_1-auc:0.99405
# [50]	validation_0-auc:0.99693	validation_1-auc:0.99398
# [52]	validation_0-auc:0.99692	validation_1-auc:0.99396
# [54]	validation_0-auc:0.99695	validation_1-auc:0.99409
# [56]	validation_0-auc:0.99708	validation_1-auc:0.99410
# [58]	validation_0-auc:0.99715	validation_1-auc:0.99411
# [60]	validation_0-auc:0.99717	validation_1-auc:0.99415
# [62]	validation_0-auc:0.99723	validation_1-auc:0.99415
# [64]	validation_0-auc:0.99727	validation_1-auc:0.99416
# [66]	validation_0-auc:0.99740	validation_1-auc:0.99411
# [68]	validation_0-auc:0.99744	validation_1-auc:0.99413
# [70]	validation_0-auc:0.99747	validation_1-auc:0.99412
# [72]	validation_0-auc:0.99753	validation_1-auc:0.99408
# [74]	validation_0-auc:0.99758	validation_1-auc:0.99411
# [76]	validation_0-auc:0.99762	validation_1-auc:0.99414
# [78]	validation_0-auc:0.99767	validation_1-auc:0.99416
# [80]	validation_0-auc:0.99773	validation_1-auc:0.99417
# [82]	validation_0-auc:0.99776	validation_1-auc:0.99416
# [84]	validation_0-auc:0.99777	validation_1-auc:0.99416
# [86]	validation_0-auc:0.99780	validation_1-auc:0.99417
# [88]	validation_0-auc:0.99782	validation_1-auc:0.99420
# [90]	validation_0-auc:0.99785	validation_1-auc:0.99419
# [92]	validation_0-auc:0.99786	validation_1-auc:0.99411
# [94]	validation_0-auc:0.99787	validation_1-auc:0.99414
# [96]	validation_0-auc:0.99790	validation_1-auc:0.99413
# [98]	validation_0-auc:0.99793	validation_1-auc:0.99410
# [100]	validation_0-auc:0.99796	validation_1-auc:0.99413
# [102]	validation_0-auc:0.99799	validation_1-auc:0.99411
# [104]	validation_0-auc:0.99803	validation_1-auc:0.99411
# [106]	validation_0-auc:0.99806	validation_1-auc:0.99411
# [108]	validation_0-auc:0.99808	validation_1-auc:0.99411
# [110]	validation_0-auc:0.99811	validation_1-auc:0.99409
# [112]	validation_0-auc:0.99815	validation_1-auc:0.99404
# [0]	validation_0-auc:0.99019	validation_1-auc:0.97569
# [2]	validation_0-auc:0.99702	validation_1-auc:0.98758
# [4]	validation_0-auc:0.99693	validation_1-auc:0.98765
# [6]	validation_0-auc:0.99695	validation_1-auc:0.98768
# [8]	validation_0-auc:0.99698	validation_1-auc:0.98748
# [10]	validation_0-auc:0.99701	validation_1-auc:0.98743
# [12]	validation_0-auc:0.99697	validation_1-auc:0.98744
# [14]	validation_0-auc:0.99692	validation_1-auc:0.98750
# [16]	validation_0-auc:0.99692	validation_1-auc:0.98746
# [18]	validation_0-auc:0.99698	validation_1-auc:0.98784
# [20]	validation_0-auc:0.99702	validation_1-auc:0.98785
# [22]	validation_0-auc:0.99703	validation_1-auc:0.98777
# [24]	validation_0-auc:0.99703	validation_1-auc:0.98780
# [26]	validation_0-auc:0.99705	validation_1-auc:0.98777
# [28]	validation_0-auc:0.99739	validation_1-auc:0.98795
# [30]	validation_0-auc:0.99740	validation_1-auc:0.98790
# [32]	validation_0-auc:0.99739	validation_1-auc:0.98785
# [34]	validation_0-auc:0.99768	validation_1-auc:0.98801
# [36]	validation_0-auc:0.99786	validation_1-auc:0.98808
# [38]	validation_0-auc:0.99786	validation_1-auc:0.98799
# [40]	validation_0-auc:0.99788	validation_1-auc:0.98799
# [42]	validation_0-auc:0.99795	validation_1-auc:0.98796
# [44]	validation_0-auc:0.99804	validation_1-auc:0.98817
# [46]	validation_0-auc:0.99811	validation_1-auc:0.98819
# [48]	validation_0-auc:0.99825	validation_1-auc:0.98820
# [50]	validation_0-auc:0.99831	validation_1-auc:0.98819
# [52]	validation_0-auc:0.99834	validation_1-auc:0.98821
# [54]	validation_0-auc:0.99838	validation_1-auc:0.98832
# [56]	validation_0-auc:0.99841	validation_1-auc:0.98825
# [58]	validation_0-auc:0.99851	validation_1-auc:0.98839
# [60]	validation_0-auc:0.99861	validation_1-auc:0.98842
# [62]	validation_0-auc:0.99861	validation_1-auc:0.98852
# [64]	validation_0-auc:0.99867	validation_1-auc:0.98864
# [66]	validation_0-auc:0.99873	validation_1-auc:0.98864
# [68]	validation_0-auc:0.99874	validation_1-auc:0.98866
# [70]	validation_0-auc:0.99878	validation_1-auc:0.98863
# [72]	validation_0-auc:0.99882	validation_1-auc:0.98860
# [74]	validation_0-auc:0.99886	validation_1-auc:0.98861
# [76]	validation_0-auc:0.99886	validation_1-auc:0.98863
# [78]	validation_0-auc:0.99890	validation_1-auc:0.98856
# [80]	validation_0-auc:0.99892	validation_1-auc:0.98857
# [82]	validation_0-auc:0.99895	validation_1-auc:0.98864
# [84]	validation_0-auc:0.99898	validation_1-auc:0.98867
# [86]	validation_0-auc:0.99901	validation_1-auc:0.98863
# [88]	validation_0-auc:0.99904	validation_1-auc:0.98866
# [90]	validation_0-auc:0.99905	validation_1-auc:0.98870
# [92]	validation_0-auc:0.99908	validation_1-auc:0.98868
# [94]	validation_0-auc:0.99910	validation_1-auc:0.98868
# [96]	validation_0-auc:0.99910	validation_1-auc:0.98866
# [98]	validation_0-auc:0.99913	validation_1-auc:0.98871
# [100]	validation_0-auc:0.99915	validation_1-auc:0.98879
# [102]	validation_0-auc:0.99917	validation_1-auc:0.98874
# [104]	validation_0-auc:0.99919	validation_1-auc:0.98872
# [106]	validation_0-auc:0.99920	validation_1-auc:0.98878
# [108]	validation_0-auc:0.99921	validation_1-auc:0.98879
# [110]	validation_0-auc:0.99923	validation_1-auc:0.98877
# [112]	validation_0-auc:0.99925	validation_1-auc:0.98875
# [114]	validation_0-auc:0.99926	validation_1-auc:0.98876
# [116]	validation_0-auc:0.99927	validation_1-auc:0.98880
# [118]	validation_0-auc:0.99927	validation_1-auc:0.98879
# [120]	validation_0-auc:0.99929	validation_1-auc:0.98884
# [122]	validation_0-auc:0.99930	validation_1-auc:0.98883
# [124]	validation_0-auc:0.99931	validation_1-auc:0.98884
# [126]	validation_0-auc:0.99933	validation_1-auc:0.98887
# [128]	validation_0-auc:0.99934	validation_1-auc:0.98888
# [130]	validation_0-auc:0.99935	validation_1-auc:0.98886
# [132]	validation_0-auc:0.99935	validation_1-auc:0.98884
# [134]	validation_0-auc:0.99935	validation_1-auc:0.98882
# [136]	validation_0-auc:0.99936	validation_1-auc:0.98886
# [138]	validation_0-auc:0.99941	validation_1-auc:0.98884
# [140]	validation_0-auc:0.99942	validation_1-auc:0.98882
# [142]	validation_0-auc:0.99943	validation_1-auc:0.98884
# [144]	validation_0-auc:0.99944	validation_1-auc:0.98886
# [146]	validation_0-auc:0.99945	validation_1-auc:0.98887
# [148]	validation_0-auc:0.99946	validation_1-auc:0.98889
# [150]	validation_0-auc:0.99947	validation_1-auc:0.98886
# [152]	validation_0-auc:0.99948	validation_1-auc:0.98884
# [154]	validation_0-auc:0.99949	validation_1-auc:0.98887
# [156]	validation_0-auc:0.99950	validation_1-auc:0.98886
# [158]	validation_0-auc:0.99950	validation_1-auc:0.98886
# [160]	validation_0-auc:0.99951	validation_1-auc:0.98885
# [162]	validation_0-auc:0.99952	validation_1-auc:0.98885
# [164]	validation_0-auc:0.99952	validation_1-auc:0.98886
# [166]	validation_0-auc:0.99954	validation_1-auc:0.98887
# [168]	validation_0-auc:0.99955	validation_1-auc:0.98886
# [170]	validation_0-auc:0.99956	validation_1-auc:0.98888
# [172]	validation_0-auc:0.99957	validation_1-auc:0.98891
# [174]	validation_0-auc:0.99958	validation_1-auc:0.98888
# ...
# [164]	validation_0-auc:1.00000	validation_1-auc:0.98813
# [166]	validation_0-auc:1.00000	validation_1-auc:0.98813
# [168]	validation_0-auc:1.00000	validation_1-auc:0.98809
# [170]	validation_0-auc:1.00000	validation_1-auc:0.98811
# [172]	validation_0-auc:1.00000	validation_1-auc:0.98821
# [174]	validation_0-auc:1.00000	validation_1-auc:0.98817
# [176]	validation_0-auc:1.00000	validation_1-auc:0.98819
# [178]	validation_0-auc:1.00000	validation_1-auc:0.98822
# [180]	validation_0-auc:1.00000	validation_1-auc:0.98824
# [182]	validation_0-auc:1.00000	validation_1-auc:0.98824
# [184]	validation_0-auc:1.00000	validation_1-auc:0.98825
# [186]	validation_0-auc:1.00000	validation_1-auc:0.98826
# [188]	validation_0-auc:1.00000	validation_1-auc:0.99092
# [190]	validation_0-auc:1.00000	validation_1-auc:0.99089
# [192]	validation_0-auc:1.00000	validation_1-auc:0.99089
# [194]	validation_0-auc:1.00000	validation_1-auc:0.99084
# [196]	validation_0-auc:1.00000	validation_1-auc:0.99085
# [198]	validation_0-auc:1.00000	validation_1-auc:0.99086
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99088
# [202]	validation_0-auc:1.00000	validation_1-auc:0.99094
# [204]	validation_0-auc:1.00000	validation_1-auc:0.99103
# [206]	validation_0-auc:1.00000	validation_1-auc:0.99110
# [208]	validation_0-auc:1.00000	validation_1-auc:0.99120
# [210]	validation_0-auc:1.00000	validation_1-auc:0.99116
# [212]	validation_0-auc:1.00000	validation_1-auc:0.99121
# [214]	validation_0-auc:1.00000	validation_1-auc:0.99123
# [216]	validation_0-auc:1.00000	validation_1-auc:0.99121
# [218]	validation_0-auc:1.00000	validation_1-auc:0.99122
# [220]	validation_0-auc:1.00000	validation_1-auc:0.99122
# [222]	validation_0-auc:1.00000	validation_1-auc:0.99120
# [224]	validation_0-auc:1.00000	validation_1-auc:0.99121
# [226]	validation_0-auc:1.00000	validation_1-auc:0.99118
# [228]	validation_0-auc:1.00000	validation_1-auc:0.99118
# [230]	validation_0-auc:1.00000	validation_1-auc:0.99115
# [232]	validation_0-auc:1.00000	validation_1-auc:0.99114
# [234]	validation_0-auc:1.00000	validation_1-auc:0.99111
# [236]	validation_0-auc:1.00000	validation_1-auc:0.99117
# [238]	validation_0-auc:1.00000	validation_1-auc:0.99115
# [240]	validation_0-auc:1.00000	validation_1-auc:0.99113
# [0]	validation_0-auc:0.99156	validation_1-auc:0.98614
# [2]	validation_0-auc:0.99445	validation_1-auc:0.98950
# [4]	validation_0-auc:0.99525	validation_1-auc:0.98971
# [6]	validation_0-auc:0.99537	validation_1-auc:0.98970
# [8]	validation_0-auc:0.99540	validation_1-auc:0.98987
# [10]	validation_0-auc:0.99616	validation_1-auc:0.99020
# [12]	validation_0-auc:0.99625	validation_1-auc:0.99034
# [14]	validation_0-auc:0.99639	validation_1-auc:0.99049
# [16]	validation_0-auc:0.99645	validation_1-auc:0.99040
# [18]	validation_0-auc:0.99646	validation_1-auc:0.99066
# [20]	validation_0-auc:0.99652	validation_1-auc:0.99097
# [22]	validation_0-auc:0.99655	validation_1-auc:0.99092
# [24]	validation_0-auc:0.99657	validation_1-auc:0.99094
# [26]	validation_0-auc:0.99735	validation_1-auc:0.99100
# [28]	validation_0-auc:0.99736	validation_1-auc:0.99106
# [30]	validation_0-auc:0.99738	validation_1-auc:0.99111
# [32]	validation_0-auc:0.99739	validation_1-auc:0.99104
# [34]	validation_0-auc:0.99895	validation_1-auc:0.99416
# [36]	validation_0-auc:0.99902	validation_1-auc:0.99428
# [38]	validation_0-auc:0.99905	validation_1-auc:0.99440
# [40]	validation_0-auc:0.99908	validation_1-auc:0.99442
# [42]	validation_0-auc:0.99909	validation_1-auc:0.99446
# [44]	validation_0-auc:0.99910	validation_1-auc:0.99449
# [46]	validation_0-auc:0.99911	validation_1-auc:0.99456
# [48]	validation_0-auc:0.99912	validation_1-auc:0.99459
# [50]	validation_0-auc:0.99912	validation_1-auc:0.99468
# [52]	validation_0-auc:0.99913	validation_1-auc:0.99475
# [54]	validation_0-auc:0.99913	validation_1-auc:0.99477
# [56]	validation_0-auc:0.99913	validation_1-auc:0.99480
# [58]	validation_0-auc:0.99914	validation_1-auc:0.99481
# [60]	validation_0-auc:0.99914	validation_1-auc:0.99487
# [62]	validation_0-auc:0.99914	validation_1-auc:0.99490
# [64]	validation_0-auc:0.99914	validation_1-auc:0.99496
# [66]	validation_0-auc:0.99914	validation_1-auc:0.99501
# [68]	validation_0-auc:0.99914	validation_1-auc:0.99506
# [70]	validation_0-auc:0.99914	validation_1-auc:0.99508
# [72]	validation_0-auc:0.99914	validation_1-auc:0.99514
# [74]	validation_0-auc:0.99914	validation_1-auc:0.99515
# [76]	validation_0-auc:0.99914	validation_1-auc:0.99517
# [78]	validation_0-auc:0.99914	validation_1-auc:0.99517
# [80]	validation_0-auc:0.99914	validation_1-auc:0.99521
# [82]	validation_0-auc:0.99914	validation_1-auc:0.99524
# [84]	validation_0-auc:0.99914	validation_1-auc:0.99528
# [86]	validation_0-auc:0.99990	validation_1-auc:0.99528
# [88]	validation_0-auc:0.99990	validation_1-auc:0.99529
# [90]	validation_0-auc:0.99992	validation_1-auc:0.99533
# [92]	validation_0-auc:0.99992	validation_1-auc:0.99535
# [94]	validation_0-auc:0.99992	validation_1-auc:0.99535
# [96]	validation_0-auc:0.99992	validation_1-auc:0.99534
# [98]	validation_0-auc:0.99993	validation_1-auc:0.99535
# [100]	validation_0-auc:0.99993	validation_1-auc:0.99532
# [102]	validation_0-auc:0.99994	validation_1-auc:0.99529
# [104]	validation_0-auc:0.99994	validation_1-auc:0.99530
# [106]	validation_0-auc:0.99995	validation_1-auc:0.99532
# [108]	validation_0-auc:0.99995	validation_1-auc:0.99531
# [110]	validation_0-auc:0.99996	validation_1-auc:0.99528
# [112]	validation_0-auc:0.99996	validation_1-auc:0.99529
# [114]	validation_0-auc:0.99996	validation_1-auc:0.99526
# [116]	validation_0-auc:0.99996	validation_1-auc:0.99528
# [118]	validation_0-auc:0.99997	validation_1-auc:0.99531
# [120]	validation_0-auc:0.99997	validation_1-auc:0.99529
# [122]	validation_0-auc:0.99997	validation_1-auc:0.99530
# [0]	validation_0-auc:0.98705	validation_1-auc:0.99043
# [2]	validation_0-auc:0.99189	validation_1-auc:0.99091
# [4]	validation_0-auc:0.99198	validation_1-auc:0.99107
# [6]	validation_0-auc:0.99320	validation_1-auc:0.99146
# [8]	validation_0-auc:0.99346	validation_1-auc:0.99157
# [10]	validation_0-auc:0.99370	validation_1-auc:0.99210
# [12]	validation_0-auc:0.99455	validation_1-auc:0.99207
# [14]	validation_0-auc:0.99539	validation_1-auc:0.99227
# [16]	validation_0-auc:0.99624	validation_1-auc:0.99234
# [18]	validation_0-auc:0.99716	validation_1-auc:0.99236
# [20]	validation_0-auc:0.99724	validation_1-auc:0.99234
# [22]	validation_0-auc:0.99885	validation_1-auc:0.99238
# [24]	validation_0-auc:0.99894	validation_1-auc:0.99249
# [26]	validation_0-auc:0.99898	validation_1-auc:0.99257
# [28]	validation_0-auc:0.99902	validation_1-auc:0.99253
# [30]	validation_0-auc:0.99905	validation_1-auc:0.99256
# [32]	validation_0-auc:0.99908	validation_1-auc:0.99266
# [34]	validation_0-auc:0.99909	validation_1-auc:0.99293
# [36]	validation_0-auc:0.99911	validation_1-auc:0.99299
# [38]	validation_0-auc:0.99912	validation_1-auc:0.99299
# [40]	validation_0-auc:0.99913	validation_1-auc:0.99292
# [42]	validation_0-auc:0.99913	validation_1-auc:0.99295
# [44]	validation_0-auc:0.99914	validation_1-auc:0.99295
# [46]	validation_0-auc:0.99914	validation_1-auc:0.99294
# [48]	validation_0-auc:0.99915	validation_1-auc:0.99299
# [50]	validation_0-auc:0.99915	validation_1-auc:0.99305
# [52]	validation_0-auc:0.99915	validation_1-auc:0.99314
# [54]	validation_0-auc:0.99915	validation_1-auc:0.99319
# [56]	validation_0-auc:0.99915	validation_1-auc:0.99322
# [58]	validation_0-auc:0.99915	validation_1-auc:0.99332
# [60]	validation_0-auc:0.99915	validation_1-auc:0.99338
# [62]	validation_0-auc:0.99915	validation_1-auc:0.99342
# [64]	validation_0-auc:0.99915	validation_1-auc:0.99344
# [66]	validation_0-auc:0.99991	validation_1-auc:0.99349
# [68]	validation_0-auc:0.99993	validation_1-auc:0.99350
# [70]	validation_0-auc:0.99993	validation_1-auc:0.99351
# [72]	validation_0-auc:0.99993	validation_1-auc:0.99356
# [74]	validation_0-auc:0.99994	validation_1-auc:0.99355
# [76]	validation_0-auc:0.99995	validation_1-auc:0.99356
# [78]	validation_0-auc:0.99995	validation_1-auc:0.99354
# [80]	validation_0-auc:0.99995	validation_1-auc:0.99361
# [82]	validation_0-auc:0.99996	validation_1-auc:0.99360
# [84]	validation_0-auc:0.99996	validation_1-auc:0.99363
# [86]	validation_0-auc:0.99997	validation_1-auc:0.99366
# [88]	validation_0-auc:0.99997	validation_1-auc:0.99365
# [90]	validation_0-auc:0.99997	validation_1-auc:0.99367
# [92]	validation_0-auc:0.99997	validation_1-auc:0.99367
# [94]	validation_0-auc:0.99998	validation_1-auc:0.99369
# [96]	validation_0-auc:0.99998	validation_1-auc:0.99369
# [98]	validation_0-auc:0.99998	validation_1-auc:0.99370
# [100]	validation_0-auc:0.99998	validation_1-auc:0.99372
# [102]	validation_0-auc:0.99998	validation_1-auc:0.99377
# [104]	validation_0-auc:0.99998	validation_1-auc:0.99380
# [106]	validation_0-auc:0.99999	validation_1-auc:0.99376
# [108]	validation_0-auc:0.99999	validation_1-auc:0.99378
# [110]	validation_0-auc:0.99999	validation_1-auc:0.99380
# [112]	validation_0-auc:0.99999	validation_1-auc:0.99375
# [114]	validation_0-auc:0.99999	validation_1-auc:0.99376
# [116]	validation_0-auc:0.99999	validation_1-auc:0.99378
# [118]	validation_0-auc:0.99999	validation_1-auc:0.99375
# [120]	validation_0-auc:0.99999	validation_1-auc:0.99376
# [122]	validation_0-auc:0.99999	validation_1-auc:0.99377
# [124]	validation_0-auc:0.99999	validation_1-auc:0.99379
# [126]	validation_0-auc:0.99999	validation_1-auc:0.99382
# [128]	validation_0-auc:0.99999	validation_1-auc:0.99381
# [130]	validation_0-auc:0.99999	validation_1-auc:0.99385
# [132]	validation_0-auc:0.99999	validation_1-auc:0.99388
# [134]	validation_0-auc:0.99999	validation_1-auc:0.99386
# [136]	validation_0-auc:0.99999	validation_1-auc:0.99389
# [138]	validation_0-auc:0.99999	validation_1-auc:0.99390
# [140]	validation_0-auc:0.99999	validation_1-auc:0.99389
# [142]	validation_0-auc:1.00000	validation_1-auc:0.99389
# [144]	validation_0-auc:1.00000	validation_1-auc:0.99391
# [146]	validation_0-auc:1.00000	validation_1-auc:0.99392
# [148]	validation_0-auc:1.00000	validation_1-auc:0.99393
# [150]	validation_0-auc:1.00000	validation_1-auc:0.99395
# [152]	validation_0-auc:1.00000	validation_1-auc:0.99397
# [154]	validation_0-auc:1.00000	validation_1-auc:0.99397
# [156]	validation_0-auc:1.00000	validation_1-auc:0.99399
# [158]	validation_0-auc:1.00000	validation_1-auc:0.99399
# [160]	validation_0-auc:1.00000	validation_1-auc:0.99402
# [162]	validation_0-auc:1.00000	validation_1-auc:0.99403
# [164]	validation_0-auc:1.00000	validation_1-auc:0.99405
# [166]	validation_0-auc:1.00000	validation_1-auc:0.99407
# [168]	validation_0-auc:1.00000	validation_1-auc:0.99411
# [170]	validation_0-auc:1.00000	validation_1-auc:0.99411
# [172]	validation_0-auc:1.00000	validation_1-auc:0.99413
# [174]	validation_0-auc:1.00000	validation_1-auc:0.99415
# [176]	validation_0-auc:1.00000	validation_1-auc:0.99413
# [178]	validation_0-auc:1.00000	validation_1-auc:0.99414
# [180]	validation_0-auc:1.00000	validation_1-auc:0.99414
# [182]	validation_0-auc:1.00000	validation_1-auc:0.99413
# [184]	validation_0-auc:1.00000	validation_1-auc:0.99413
# [186]	validation_0-auc:1.00000	validation_1-auc:0.99417
# [188]	validation_0-auc:1.00000	validation_1-auc:0.99415
# [190]	validation_0-auc:1.00000	validation_1-auc:0.99414
# [192]	validation_0-auc:1.00000	validation_1-auc:0.99415
# [194]	validation_0-auc:1.00000	validation_1-auc:0.99416
# [196]	validation_0-auc:1.00000	validation_1-auc:0.99415
# [198]	validation_0-auc:1.00000	validation_1-auc:0.99414
# [200]	validation_0-auc:1.00000	validation_1-auc:0.99412
# [202]	validation_0-auc:1.00000	validation_1-auc:0.99412
# [204]	validation_0-auc:1.00000	validation_1-auc:0.99413
# [206]	validation_0-auc:1.00000	validation_1-auc:0.99412
# [208]	validation_0-auc:1.00000	validation_1-auc:0.99413
# [210]	validation_0-auc:1.00000	validation_1-auc:0.99412
# [211]	validation_0-auc:1.00000	validation_1-auc:0.99412
# [0]	validation_0-auc:0.99181	validation_1-auc:0.97725
# [2]	validation_0-auc:0.99413	validation_1-auc:0.97810
# [4]	validation_0-auc:0.99442	validation_1-auc:0.97820
# [6]	validation_0-auc:0.99450	validation_1-auc:0.97857
# [8]	validation_0-auc:0.99462	validation_1-auc:0.97889
# [10]	validation_0-auc:0.99465	validation_1-auc:0.97922
# [12]	validation_0-auc:0.99469	validation_1-auc:0.97927
# [14]	validation_0-auc:0.99470	validation_1-auc:0.97918
# [16]	validation_0-auc:0.99483	validation_1-auc:0.97921
# [18]	validation_0-auc:0.99491	validation_1-auc:0.97931
# [20]	validation_0-auc:0.99496	validation_1-auc:0.97951
# [22]	validation_0-auc:0.99498	validation_1-auc:0.97952
# [24]	validation_0-auc:0.99576	validation_1-auc:0.97972
# [26]	validation_0-auc:0.99655	validation_1-auc:0.97960
# [28]	validation_0-auc:0.99733	validation_1-auc:0.98273
# [30]	validation_0-auc:0.99812	validation_1-auc:0.98287
# [32]	validation_0-auc:0.99817	validation_1-auc:0.98290
# [34]	validation_0-auc:0.99897	validation_1-auc:0.99197
# [36]	validation_0-auc:0.99899	validation_1-auc:0.99189
# [38]	validation_0-auc:0.99902	validation_1-auc:0.99208
# [40]	validation_0-auc:0.99906	validation_1-auc:0.99227
# [42]	validation_0-auc:0.99909	validation_1-auc:0.99238
# [44]	validation_0-auc:0.99910	validation_1-auc:0.99238
# [46]	validation_0-auc:0.99911	validation_1-auc:0.99244
# [48]	validation_0-auc:0.99912	validation_1-auc:0.99247
# [50]	validation_0-auc:0.99913	validation_1-auc:0.99249
# [52]	validation_0-auc:0.99914	validation_1-auc:0.99259
# [54]	validation_0-auc:0.99914	validation_1-auc:0.99265
# [56]	validation_0-auc:0.99914	validation_1-auc:0.99267
# [58]	validation_0-auc:0.99915	validation_1-auc:0.99271
# [60]	validation_0-auc:0.99915	validation_1-auc:0.99273
# [62]	validation_0-auc:0.99915	validation_1-auc:0.99277
# [64]	validation_0-auc:0.99915	validation_1-auc:0.99279
# [66]	validation_0-auc:0.99990	validation_1-auc:0.99283
# [68]	validation_0-auc:0.99992	validation_1-auc:0.99285
# [70]	validation_0-auc:0.99993	validation_1-auc:0.99289
# [72]	validation_0-auc:0.99993	validation_1-auc:0.99295
# [74]	validation_0-auc:0.99994	validation_1-auc:0.99291
# [76]	validation_0-auc:0.99995	validation_1-auc:0.99291
# [78]	validation_0-auc:0.99995	validation_1-auc:0.99298
# [80]	validation_0-auc:0.99995	validation_1-auc:0.99300
# [82]	validation_0-auc:0.99996	validation_1-auc:0.99301
# [84]	validation_0-auc:0.99996	validation_1-auc:0.99300
# [86]	validation_0-auc:0.99996	validation_1-auc:0.99304
# [88]	validation_0-auc:0.99997	validation_1-auc:0.99307
# [90]	validation_0-auc:0.99997	validation_1-auc:0.99306
# [92]	validation_0-auc:0.99997	validation_1-auc:0.99306
# [94]	validation_0-auc:0.99997	validation_1-auc:0.99309
# [96]	validation_0-auc:0.99998	validation_1-auc:0.99306
# [98]	validation_0-auc:0.99998	validation_1-auc:0.99307
# [100]	validation_0-auc:0.99998	validation_1-auc:0.99308
# [102]	validation_0-auc:0.99998	validation_1-auc:0.99306
# [104]	validation_0-auc:0.99998	validation_1-auc:0.99306
# [106]	validation_0-auc:0.99998	validation_1-auc:0.99308
# [108]	validation_0-auc:0.99999	validation_1-auc:0.99311
# [110]	validation_0-auc:0.99999	validation_1-auc:0.99315
# [112]	validation_0-auc:0.99999	validation_1-auc:0.99316
# [114]	validation_0-auc:0.99999	validation_1-auc:0.99319
# [116]	validation_0-auc:0.99999	validation_1-auc:0.99317
# [118]	validation_0-auc:0.99999	validation_1-auc:0.99321
# [120]	validation_0-auc:0.99999	validation_1-auc:0.99319
# [122]	validation_0-auc:0.99999	validation_1-auc:0.99320
# [124]	validation_0-auc:1.00000	validation_1-auc:0.99323
# [126]	validation_0-auc:1.00000	validation_1-auc:0.99324
# [128]	validation_0-auc:1.00000	validation_1-auc:0.99323
# [130]	validation_0-auc:1.00000	validation_1-auc:0.99324
# [132]	validation_0-auc:1.00000	validation_1-auc:0.99323
# [134]	validation_0-auc:1.00000	validation_1-auc:0.99323
# [136]	validation_0-auc:1.00000	validation_1-auc:0.99323
# [138]	validation_0-auc:1.00000	validation_1-auc:0.99321
# [140]	validation_0-auc:1.00000	validation_1-auc:0.99324
# [142]	validation_0-auc:1.00000	validation_1-auc:0.99321
# [144]	validation_0-auc:1.00000	validation_1-auc:0.99321
# [146]	validation_0-auc:1.00000	validation_1-auc:0.99319
# [148]	validation_0-auc:1.00000	validation_1-auc:0.99319
# [150]	validation_0-auc:1.00000	validation_1-auc:0.99320
# [151]	validation_0-auc:1.00000	validation_1-auc:0.99320
# 5it [04:29, 53.99s/it]
# 2it [08:19, 249.80s/it]
# 5fold f1: 0.8386185243328101
# all f1: 0.8419558431325924, auc: 0.9916691776422732
# round 2,  all seed f1: 0.8419558431325924, all seed auc: 0.9916691776422732

# %%
y_pred_all_para_mean = np.column_stack(y_pred_all_para).mean(axis=1)
y_submit_all_para_mean = np.column_stack(y_submit_all_para).mean(axis=1)
f1 = my_metric(train['label'], np.where(y_pred_all_para_mean >= 0.5, 1, 0), sample_weight=train['sample_weight'])
auc = roc_auc_score(train['label'], y_pred_all_para_mean, sample_weight=train['sample_weight'])
print(f'all para mean f1: {f1}, all para mean auc: {auc}')
# Out:
# all para mean f1: 0.8449814618621958, all para mean auc: 0.9895034611816387

# %%
def find_best_t(y_pred, y_true):
    best_score = my_metric(y_true, np.where(y_pred >= 0.5, 1, 0))
    t = 0.5
    for i in tqdm(range(450, 551)):
        current_score = my_metric(y_true, np.where(y_pred >= i / 1000, 1, 0))
        if current_score > best_score:
            best_score = current_score
            t = i / 1000
            print(f'best score: {best_score}, best t: {t}')
    return t


t = find_best_t(y_pred_all_para_mean, train['label'])
# Out:
#   8%|▊         | 8/101 [00:00<00:01, 77.39it/s]
# best score: 0.8451833275618137, best t: 0.458
# best score: 0.8456652599477683, best t: 0.459
#  16%|█▌        | 16/101 [00:00<00:01, 76.18it/s]
# best score: 0.8461108331157343, best t: 0.466
# best score: 0.8465967689641821, best t: 0.467
# best score: 0.8470835675813039, best t: 0.469
# best score: 0.8475712313607365, best t: 0.47
#  24%|██▍       | 24/101 [00:00<00:01, 72.88it/s]
# best score: 0.8480475692434963, best t: 0.472
# best score: 0.8490295950367738, best t: 0.473
# 100%|██████████| 101/101 [00:01<00:00, 74.61it/s]

# %%
submit = pd.read_csv('./entprise_evaluate.csv')
submit['score'] = submit['id'].map(pd.Series(np.where(y_submit_all_para_mean >= t, 1, 0), index=X_submit['id']))
submit.to_csv('submission.csv', index=False)
